# %%
import pymongo
import os
import pandas as pd
from pandas.io.json import json_normalize

import yaml
from collections import Counter
from datetime import datetime
import sys
SRC = os.path.join(os.path.dirname(os.path.dirname(os.getcwd())), "src")
sys.path.append(SRC)
from content_api.details_utils import extract_from_details, cs_extract_text, cs_extract_links

# %%
### Get dirs

# %%
DATA_DIR = os.getenv("DATA_DIR")
config = os.path.join(SRC, "config")
black_list_path = os.path.join(config, "document_types_excluded_from_the_topic_taxonomy.yml")

# %%
with open(black_list_path, 'r') as stream:
    blacklisted_content_page = sorted(yaml.load(stream)['document_types'])
blacklisted_content_page[0:5]
# Out:
# ['about',
#  'about_our_services',
#  'access_and_opening',
#  'business_support_finder',
#  'coming_soon']

# %%
### Get database running locally

# %%
myclient = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
print(myclient.list_database_names())
# Out:
# ['admin', 'config', 'content_items', 'local']

# %%
mydb = myclient["content_items"]
mycol = mydb["content_items"]

# %%
# whitelisted_doctypes_filter = {"$elemMatch": { "document_type": {"$nin":blacklisted_content_page}, "phase":"live"}}
whitelisted_doctypes_filter = {"document_type": {"$nin": blacklisted_content_page}}

filter_ = { "$and": [{"$or": [{"expanded_links.ordered_related_items": {"$exists": True}}, {"expanded_links.documents": {"$exists": True}}]},
                    { "document_type": {"$nin": blacklisted_content_page}},
                    { "phase": "live"}]}


filter_related_links = { "$and": [{"expanded_links.ordered_related_items": {"$exists": True}},
                    { "document_type": {"$nin": blacklisted_content_page}},
                    { "phase": "live"}]}

filter_collection_links = { "$and": [{"expanded_links.documents": {"$exists": True}},
                    { "document_type": {"$nin": blacklisted_content_page}},
                    { "phase": "live"}]}

# %%
keep_projection = { 
    "expanded_links.ordered_related_items.base_path": 1,
    "expanded_links.documents.base_path": 1,
    "expanded_links.ordered_related_items.content_id": 1,
    "expanded_links.documents.content_id": 1,
    "content_id": 1}

# %%
related_links_json = list(mycol.find(filter_related_links, keep_projection))

# %%
collection_links_json = list(mycol.find(filter_collection_links, keep_projection))

# %%
related_links_df = json_normalize(related_links_json, 
                    record_path=[['expanded_links', 'ordered_related_items']], 
                    meta=['_id', 'content_id'],
                                  meta_prefix='source_'
                    )

# %%
related_links_df.columns = ['destination_base_path', 'destination_content_id', 'source_base_path', 'source_content_id']
related_links_df['link_type'] = 'related_link'

# %%
collection_links_df = json_normalize(collection_links_json, 
                    record_path=[['expanded_links', 'documents']], 
                    meta=['_id', 'content_id'], 
                                  meta_prefix='source_'
                    )

# %%
collection_links_df.columns = ['destination_base_path', 'destination_content_id', 'source_base_path', 'source_content_id'] 
collection_links_df['link_type'] = 'collection_link'

# %%
all_links = pd.concat([related_links_df, collection_links_df], axis=0, sort=False)

# %%
all_links
# Out:
#                                    destination_base_path  \
# 0                                /courses-qualifications
# 1                                       /learner-support
# 2                    /subsidised-college-transport-16-19
# 3                   /education-maintenance-allowance-ema
# 4                       /unfair-terms-in-sales-contracts
# 5            /online-and-distance-selling-for-businesses
# 6                             /product-labelling-the-law
# 7                             /business-support-helpline
# 8      /definition-of-disability-under-equality-act-2010
# 9                                /rights-disabled-person
# 10                           /disabled-facilities-grants
# 11                              /financial-help-disabled
# 12          /reasonable-adjustments-for-disabled-workers
# 13     /definition-of-disability-under-equality-act-2010
# 14                               /rights-disabled-person
# 15                         /looking-for-work-if-disabled
# 16                       /giving-up-your-driving-licence
# 17                        /health-conditions-and-driving
# 18                           /driving-medical-conditions
# 19            /reapply-driving-licence-medical-condition
# 20                                   /capital-allowances
# 21                           /correct-birth-registration
# 22          /order-copy-birth-death-marriage-certificate
# 23                  /automatic-driving-licence-to-manual
# 24                              /become-lorry-bus-driver
# 25                                     /book-theory-test
# 26                                    /book-driving-test
# 27               /track-your-driving-licence-application
# 28                           /driving-licence-categories
# 29                       /giving-up-your-driving-licence
# ...                                                  ...
# 66399    /guidance/zika-virus-symptoms-and-complications
# 66400   /guidance/zika-virus-and-guillain-barre-syndrome
# 66401   /government/publications/zika-virus-transmission
# 66402  /guidance/zika-virus-preventing-infection-by-s...
# 66403  /government/publications/zika-virus-sexual-tra...
# 66404         /guidance/zika-virus-country-specific-risk
# 66405                 /guidance/zika-virus-travel-advice
# 66406  /government/publications/mosquito-bite-avoidan...
# 66407  /government/publications/zika-virus-interim-al...
# 66408  /government/publications/zika-virus-advice-for...
# 66409  /government/publications/zika-virus-congenital...
# 66410  /government/publications/zika-virus-surveillan...
# 66411  /guidance/zika-virus-and-immunocompromised-pat...
# 66412         /guidance/zika-virus-sample-testing-advice
# 66413  /government/publications/hairs-risk-assessment...
# 66414     /government/publications/mosquito-surveillance
# 66415  /government/publications/list-of-zoonotic-dise...
# 66416  /government/publications/zoonotic-diseases-inv...
# 66417  /government/publications/zoonoses-uk-annual-re...
# 66418  /government/publications/zoonotic-diseases-sur...
# 66419  /guidance/raw-pet-foods-handling-and-preventin...
# 66420  /government/publications/farm-visits-avoiding-...
# 66421  /government/publications/mycobacterium-bovis-m...
# 66422  /government/publications/pet-rats-mice-hamster...
# 66423  /guidance/pregnancy-advice-on-contact-with-ani...
# 66424  /government/publications/q-fever-good-practice...
# 66425  /government/publications/rabies-risks-from-bat...
# 66426                           /guidance/rabies-in-bats
# 66427  /government/publications/salmonella-reducing-i...
# 66428  /government/publications/health-spa-pedicures-...
#
#                      destination_content_id  \
# 0      b4294926-5ff6-4349-8d0d-4a7d54e5de52
# 1      14bfeca4-b490-4e73-8149-08e8a30d36e9
# 2      486159ab-fac6-4397-afd4-cc3b994d8ed6
# 3      8ff35813-edb9-4727-b669-661956ce3d52
# 4      d81a9f29-dffc-4de9-9ba0-b4bdac3d1d89
# 5      38bc84a8-98a4-42ae-942d-87568d2a83d4
# 6      8f86935f-2864-414e-98a3-1ebcfd76cc97
# 7      42b1ec32-8258-4f42-8d1c-3851082d83c1
