# %%
import networkx as nx
import pandas as pd
import json
import os
from networkx.readwrite import json_graph
import numpy as np
from datetime import datetime
from node2vec import Node2Vec
from node2vec.edges import HadamardEmbedder
from ast import literal_eval
from gensim.models import Word2Vec

# %%
### Directories

# %%
DATA_DIR = os.getenv("DATA_DIR")
train_network = os.path.join(DATA_DIR, "train_network")
models = os.path.join(os.path.dirname(DATA_DIR), "models")
content_api = os.path.join(DATA_DIR, "content_api")
os.listdir(train_network)

edgefile = os.path.join(train_network, "merged_edges_struct_funct.csv.gz")
edges = pd.read_csv(edgefile, compression="gzip")

# %%
### Initialize `base_path`,  `content_id` and `feature` dictionaries

def build_dict(k1,v1,k2,v2):
    agg_dict = dict(zip(k1,v1))
    for key,value in zip(k2,v2):
        if key not in agg_dict.keys():
            agg_dict[key] = value
    return agg_dict

# %%
## Save out resulting node/edge embeddings and model.
EMBEDDING_MODEL_FILENAME = os.path.join(models, "n2v.model")

# %%
## Check some results, load saved trained model from above

model =  Word2Vec.load(EMBEDDING_MODEL_FILENAME)

# %%
str_node = "/sold-bought-vehicle"
# "/sold-bought-vehicle"/government/publications/below-the-radar-low-level-disruption-in-the-countrys-classrooms
target = str(edges[edges.src_node == str_node].source.values[0])
target
# Out:
# '61415'

# %%
count = 0
cids = []
for nid, prob in model.wv.most_similar(target, topn=50):
    if nid_cid[int(target)] != nid_cid[int(nid)] and "/browse" not in nid_url[int(nid)]\
    and nid_cid[int(nid)] not in cids:
        print(nid_url[int(nid)])
        count+=1
        cids.append(nid_cid[int(nid)])
    if count == 10:
        break
# Out:
# /make-a-sorn
# /vehicle-tax-refund
# /vehicle-log-book
# /car-tax-disc-without-v11-reminder
# /responsibilities-selling-vehicle
# /sorn-statutory-off-road-notification
# /contact-the-dvla
# /government/publications/application-for-a-vehicle-registration-certificate
# /check-vehicle-tax
# /written-off-vehicle
# /Users/felisialoukou/.pyenv/versions/3.6.0/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %% [markdown]
# ## "Predict" for top 50 pages

# %%
## Brexit docs
bq = os.path.join(DATA_DIR, "bq_journey_extract")
bfile = os.path.join(bq, "Brexit-related documents - Brexit docs.tsv")
df1 = pd.read_csv(bfile, sep="\t")
df1.columns
# Out:
# Index(['1917', 'Unnamed: 1', 'Last run on: ', '2019-03-31 09:42:51',
#        'Unnamed: 4'],
#       dtype='object')

# %%
df1.drop(['Last run on: ', '2019-03-31 09:42:51',
       'Unnamed: 4'], axis=1, inplace=True)
df1.rename(columns={"1917":"URL","Unnamed: 1":"Pageviews"}, inplace=True)
df1.drop([0,1], inplace=True)
df1 = df1[~df1.URL.str.contains("/print/")]
df1['Pageviews'] = df1['Pageviews'].map(lambda x: x.replace(',', '') 
                                        if isinstance(x,str) else np.nan)
df1['Pageviews'] = df1['Pageviews'].astype("float")
df1.shape
# Out:
# (1562, 2)

# %%
df1.Pageviews.describe()
# Out:
# count      1381.000000
# mean       2206.220854
# std       16089.879061
# min           2.000000
# 25%           6.000000
# 50%          34.000000
# 75%         266.000000
# max      341728.000000
# Name: Pageviews, dtype: float64

# %%
df1 = df1[df1.Pageviews>1]
df1.shape
# Out:
# (1381, 2)

# %%
df1.head()
# Out:
#                                                  URL  Pageviews
# 2  /guidance/international-driving-permits-for-uk...   341728.0
# 3                             /staying-uk-eu-citizen   311799.0
# 4               /settled-status-eu-citizens-families   185997.0
# 5                                   /prepare-eu-exit   138898.0
# 6  /settled-status-eu-citizens-families/applying-...   129524.0

# %%
### Generate vectors

# %%
def generate_vectors(vector_list):
    for nid, prob in vector_list:
        yield nid, prob

# %%
## Test funct
vecs = generate_vectors(model.wv.most_similar("0", topn=1000))
nid, prob = next(vecs)
nid, prob
# Out:
# /Users/felisialoukou/.pyenv/versions/3.6.0/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# ('22461', 0.8493591547012329)

# %%
## Compute related links for a set of pages
nid_cid = build_dict(edges.source, edges.src_cid, edges.target, edges.dest_cid)
nid_url = build_dict(edges.source, edges.src_node, edges.target, edges.dest_node)
url_nid = build_dict(edges.src_node, edges.source, edges.dest_node, edges.target)

# %%
ignore_urls = ["/topic","/browse", "/help", "/cookies", "/email", "/y/", "/no/"]
def compute_top_n(df_path, n):
    pages_links = []
    missing = []
    for page in df_path.values:
        if page in url_nid.keys():
            target = str(url_nid[page])
            count = 0
            cids = []
            vecs = generate_vectors(model.wv.most_similar(target, topn=2000))
            while count <= n:
                nid, prob = next(vecs)
                if nid_cid[int(target)] != nid_cid[int(nid)]\
                and all(cond not in nid_url[int(nid)] for cond in ignore_urls)\
                and all(not nid_url[int(nid)].endswith(cond) for cond in ["/y", "/no"])\
                and nid_cid[int(nid)] not in cids:
                
#                 and nid_cid[int(nid)] not in cid_link_cids[nid_cid[int(target)]]:
                    
                    cids.append(nid_cid[int(nid)])
                    page_link = {"nid":int(target),
                                 "cid":nid_cid[int(target)],
                                 "base_path": page, 
                                 "link":nid_url[int(nid)], 
                                 "link_cid":nid_cid[int(nid)],
                                 "probability":round(prob,3)}
                    pages_links.append(page_link)
                    count+=1
        else:
            missing.append(page)
#             print("Page {} is missing from training set".format(page))
            
    return pd.DataFrame(pages_links), missing

# %%
top_250 = df1.sort_values("Pageviews", ascending=False).URL
results, misses = compute_top_n(top_250, 10)
results.shape, len(misses), len(set(top_250))-len(misses)
# Out:
# ((6127, 6), 824, 557)

# %%
top_250.shape
# Out:
# (1381,)

# %%
results
# Out:
#                                               base_path  \
# 0     /guidance/international-driving-permits-for-uk...
# 1     /guidance/international-driving-permits-for-uk...
# 2     /guidance/international-driving-permits-for-uk...
# 3     /guidance/international-driving-permits-for-uk...
# 4     /guidance/international-driving-permits-for-uk...
# 5     /guidance/international-driving-permits-for-uk...
# 6     /guidance/international-driving-permits-for-uk...
# 7     /guidance/international-driving-permits-for-uk...
# 8     /guidance/international-driving-permits-for-uk...
# 9     /guidance/international-driving-permits-for-uk...
# 10    /guidance/international-driving-permits-for-uk...
# 11                               /staying-uk-eu-citizen
# 12                               /staying-uk-eu-citizen
# 13                               /staying-uk-eu-citizen
# 14                               /staying-uk-eu-citizen
# 15                               /staying-uk-eu-citizen
# 16                               /staying-uk-eu-citizen
# 17                               /staying-uk-eu-citizen
# 18                               /staying-uk-eu-citizen
# 19                               /staying-uk-eu-citizen
# 20                               /staying-uk-eu-citizen
# 21                               /staying-uk-eu-citizen
# 22                 /settled-status-eu-citizens-families
# 23                 /settled-status-eu-citizens-families
# 24                 /settled-status-eu-citizens-families
# 25                 /settled-status-eu-citizens-families
# 26                 /settled-status-eu-citizens-families
# 27                 /settled-status-eu-citizens-families
# 28                 /settled-status-eu-citizens-families
# 29                 /settled-status-eu-citizens-families
# ...                                                 ...
# 6097  /government/news/david-davis-closing-remarks-a...
# 6098  /government/news/david-davis-closing-remarks-a...
# 6099  /government/news/david-davis-closing-remarks-a...
# 6100  /government/news/david-davis-closing-remarks-a...
# 6101  /government/news/david-davis-closing-remarks-a...
# 6102  /government/news/david-davis-closing-remarks-a...
# 6103  /government/news/david-davis-closing-remarks-a...
# 6104  /government/news/david-davis-closing-remarks-a...
# 6105  /government/news/david-davis-closing-remarks-a...
# 6106  /government/news/david-davis-closing-remarks-a...
# 6107  /government/news/david-davis-closing-remarks-a...
# 6108  /government/news/david-davis-closing-remarks-a...
# 6109  /government/news/david-davis-closing-remarks-a...
# 6110  /government/news/david-davis-closing-remarks-a...
# 6111  /government/news/david-davis-closing-remarks-a...
# 6112  /government/news/david-davis-closing-remarks-a...
# 6113  /government/news/david-davis-closing-remarks-a...
# 6114  /government/news/david-davis-closing-remarks-a...
# 6115  /government/news/david-davis-closing-remarks-a...
# 6116  /government/news/david-davis-foundations-of-th...
# 6117  /government/news/david-davis-foundations-of-th...
# 6118  /government/news/david-davis-foundations-of-th...
# 6119  /government/news/david-davis-foundations-of-th...
# 6120  /government/news/david-davis-foundations-of-th...
# 6121  /government/news/david-davis-foundations-of-th...
# 6122  /government/news/david-davis-foundations-of-th...
# 6123  /government/news/david-davis-foundations-of-th...
# 6124  /government/news/david-davis-foundations-of-th...
# 6125  /government/news/david-davis-foundations-of-th...
# 6126  /government/news/david-davis-foundations-of-th...
#
#                                        cid  \
# 0     87402d3f-e799-4d32-bfed-b0880f7c3b4e
# 1     87402d3f-e799-4d32-bfed-b0880f7c3b4e
# 2     87402d3f-e799-4d32-bfed-b0880f7c3b4e
# 3     87402d3f-e799-4d32-bfed-b0880f7c3b4e
# 4     87402d3f-e799-4d32-bfed-b0880f7c3b4e
# 5     87402d3f-e799-4d32-bfed-b0880f7c3b4e
# 6     87402d3f-e799-4d32-bfed-b0880f7c3b4e
# 7     87402d3f-e799-4d32-bfed-b0880f7c3b4e
# 8     87402d3f-e799-4d32-bfed-b0880f7c3b4e
# 9     87402d3f-e799-4d32-bfed-b0880f7c3b4e
# 10    87402d3f-e799-4d32-bfed-b0880f7c3b4e
# 11    b51139f9-8da7-4e97-ad5d-d91c73d5b5b2
# 12    b51139f9-8da7-4e97-ad5d-d91c73d5b5b2
# 13    b51139f9-8da7-4e97-ad5d-d91c73d5b5b2
# 14    b51139f9-8da7-4e97-ad5d-d91c73d5b5b2
# 15    b51139f9-8da7-4e97-ad5d-d91c73d5b5b2
# 16    b51139f9-8da7-4e97-ad5d-d91c73d5b5b2
# 17    b51139f9-8da7-4e97-ad5d-d91c73d5b5b2
# 18    b51139f9-8da7-4e97-ad5d-d91c73d5b5b2
# 19    b51139f9-8da7-4e97-ad5d-d91c73d5b5b2
# 20    b51139f9-8da7-4e97-ad5d-d91c73d5b5b2
# 21    b51139f9-8da7-4e97-ad5d-d91c73d5b5b2
# 22    91504a10-f697-42a3-a779-f238b4955ea9
# 23    91504a10-f697-42a3-a779-f238b4955ea9
# 24    91504a10-f697-42a3-a779-f238b4955ea9
# 25    91504a10-f697-42a3-a779-f238b4955ea9
# 26    91504a10-f697-42a3-a779-f238b4955ea9
# 27    91504a10-f697-42a3-a779-f238b4955ea9
# 28    91504a10-f697-42a3-a779-f238b4955ea9
# 29    91504a10-f697-42a3-a779-f238b4955ea9
# ...                                    ...
# 6097  48e6cc1b-bb73-4979-9595-8d92615d4e2f
# 6098  48e6cc1b-bb73-4979-9595-8d92615d4e2f
# 6099  48e6cc1b-bb73-4979-9595-8d92615d4e2f
# 6100  48e6cc1b-bb73-4979-9595-8d92615d4e2f
# 6101  48e6cc1b-bb73-4979-9595-8d92615d4e2f
# 6102  48e6cc1b-bb73-4979-9595-8d92615d4e2f
# 6103  48e6cc1b-bb73-4979-9595-8d92615d4e2f
# 6104  48e6cc1b-bb73-4979-9595-8d92615d4e2f
# 6105  2340daa9-d094-4889-91ab-31c80c666350
# 6106  2340daa9-d094-4889-91ab-31c80c666350
# 6107  2340daa9-d094-4889-91ab-31c80c666350
# 6108  2340daa9-d094-4889-91ab-31c80c666350
# 6109  2340daa9-d094-4889-91ab-31c80c666350
# 6110  2340daa9-d094-4889-91ab-31c80c666350
# 6111  2340daa9-d094-4889-91ab-31c80c666350
# 6112  2340daa9-d094-4889-91ab-31c80c666350
# 6113  2340daa9-d094-4889-91ab-31c80c666350
# 6114  2340daa9-d094-4889-91ab-31c80c666350
# 6115  2340daa9-d094-4889-91ab-31c80c666350
# 6116  8fcffd30-194a-4633-b03b-50325e337c75
# 6117  8fcffd30-194a-4633-b03b-50325e337c75
# 6118  8fcffd30-194a-4633-b03b-50325e337c75
# 6119  8fcffd30-194a-4633-b03b-50325e337c75
# 6120  8fcffd30-194a-4633-b03b-50325e337c75
# 6121  8fcffd30-194a-4633-b03b-50325e337c75
# 6122  8fcffd30-194a-4633-b03b-50325e337c75
# 6123  8fcffd30-194a-4633-b03b-50325e337c75
# 6124  8fcffd30-194a-4633-b03b-50325e337c75
# 6125  8fcffd30-194a-4633-b03b-50325e337c75
# 6126  8fcffd30-194a-4633-b03b-50325e337c75
#
#                                                    link  \
# 0     /guidance/prepare-to-drive-in-the-eu-after-brexit
# 1     /government/publications/driving-in-the-eu-if-...
# 2     /guidance/passenger-travel-to-the-eu-by-air-ra...
# 3     /government/publications/prepare-to-drive-in-t...
# 4                        /guidance/trailer-registration
# 5                            /prepare-eu-exit/transport
# 6          /driving-abroad/international-driving-permit
# 7               /prepare-eu-exit/going-and-being-abroad
# 8                     /vehicle-insurance/driving-abroad
# 9     /taking-vehicles-out-of-uk/for-less-than-12-mo...
# 10    /government/publications/vehicle-insurance-if-...
# 11                                     /prepare-eu-exit
# 12                              /uk-nationals-living-eu
# 13                 /settled-status-eu-citizens-families
# 14    /guidance/using-the-eu-exit-id-document-check-app
# 15                              /business-uk-leaving-eu
# 16        /uk-residence-eu-citizens/permanent-residence
# 17    /guidance/eu-settlement-scheme-evidence-of-uk-...
# 18                                /apply-renew-passport
# 19                       /apply-for-a-uk-residence-card
# 20    /government/collections/eu-settlement-scheme-a...
# 21                                     /eusettledstatus
# 22    /guidance/using-the-eu-exit-id-document-check-app
# 23    /government/publications/policy-paper-on-citiz...
# 24    /government/collections/eu-settlement-scheme-a...
# 25        /uk-residence-eu-citizens/permanent-residence
# 26                               /staying-uk-eu-citizen
# 27                                     /eusettledstatus
# 28                       /apply-for-a-uk-residence-card
# 29    /guidance/eu-settlement-scheme-evidence-of-uk-...
# ...                                                 ...
# 6097  /government/publications/terms-of-reference-fo...
# 6098  /government/publications/privileges-and-immuni...
# 6099  /government/publications/technical-note-on-exi...
# 6100  /government/publications/confidentiality-and-a...
# 6101  /government/news/secretary-of-state-statement-...
# 6102  /government/news/programme-for-fifth-round-of-...
# 6103  /government/news/programme-for-third-round-of-...
# 6104  /government/publications/technical-note-on-fun...
# 6105  /government/speeches/secretary-of-state-update...
# 6106  /government/news/britain-seeks-comprehensive-s...
# 6107  /government/publications/technical-note-on-exi...
# 6108  /government/news/david-davis-update-to-the-hou...
# 6109  /government/speeches/prime-ministers-commons-s...
# 6110  /government/speeches/exiting-the-european-unio...
# 6111  /government/news/secretary-of-state-david-davi...
# 6112  /government/news/secretary-of-state-update-to-...
# 6113  /government/publications/ongoing-union-judicia...
# 6114  /government/news/programme-eu-uk-article-50-ne...
# 6115  /government/publications/customs-bill-legislat...
# 6116  /government/news/britain-seeks-comprehensive-s...
# 6117  /government/speeches/secretary-of-state-update...
# 6118  /government/speeches/pm-commons-statement-on-e...
# 6119  /government/publications/uk-science-and-innova...
# 6120  /government/publications/bottled-and-mineral-w...
# 6121  /government/consultations/improving-the-costin...
# 6122  /government/publications/ts23-4ha-marlow-foods...
# 6123  /government/publications/complaint-from-justic...
# 6124        /government/publications/laos-consular-fees
# 6125  /government/consultations/reimbursement-of-urg...
# 6126  /government/publications/msn-1671-amendment-1-...
#
#                                   link_cid    nid  probability
# 0     9f1621c2-1d3c-4a91-ad71-5366d3270dae  23749        0.965
# 1     be15abf2-86fc-4bfc-9f76-edaac6346799  23749        0.878
# 2     dc917169-0dbb-48ea-b8be-afd8573cf6e7  23749        0.860
# 3     c1a32196-47f3-47bb-a199-f03d49db6d92  23749        0.846
# 4     f8ce6166-5069-4a43-a92d-5628027106ec  23749        0.838
# 5     2d4ac9b6-d783-47d6-a3ce-4c51b0e697f9  23749        0.805
# 6     e4d06cb9-9e2e-4e82-b802-0aad013ae16c  23749        0.781
# 7     d37a4cad-42ee-4a82-bb91-7de603848c72  23749        0.774
# 8     5305660e-bfba-4c41-b170-96dcfcf88099  23749        0.753
# 9     406a1b8d-acaa-46fe-9296-f5a05508a303  23749        0.742
# 10    00a39dcb-1c94-4c0d-8e62-a55275d52c8f  23749        0.737
# 11    ecb55f9d-0823-43bd-a116-dbfab2b76ef9  46386        0.973
# 12    7a99da17-e9e1-410b-b67d-c3f6348c595d  46386        0.867
# 13    91504a10-f697-42a3-a779-f238b4955ea9  46386        0.772
# 14    b1059fb6-ecdc-468f-9281-5ab232559727  46386        0.677
# 15    c4253ae7-2f24-49fe-92cc-5d8110377466  46386        0.667
# 16    722dd24b-a8a8-4e51-a457-f17197bd5dfe  46386        0.666
# 17    1d1ec077-2f48-4289-a6e2-41a7a1647afd  46386        0.661
# 18    a350d322-669c-4acc-8b54-08c342afd569  46386        0.641
# 19    585fc781-dc17-4a1d-a66c-9515f9970ab5  46386        0.641
# 20    c2b0ee89-9986-4022-be50-00a99533543a  46386        0.637
# 21    0c79b832-75de-4854-8154-d62774a8dfb8  46386        0.622
# 22    b1059fb6-ecdc-468f-9281-5ab232559727  55850        0.814
# 23    fdcc0a00-5683-47c4-9e17-9b81bb41d9b7  55850        0.814
# 24    c2b0ee89-9986-4022-be50-00a99533543a  55850        0.801
# 25    722dd24b-a8a8-4e51-a457-f17197bd5dfe  55850        0.784
# 26    b51139f9-8da7-4e97-ad5d-d91c73d5b5b2  55850        0.772
# 27    0c79b832-75de-4854-8154-d62774a8dfb8  55850        0.762
# 28    585fc781-dc17-4a1d-a66c-9515f9970ab5  55850        0.755
# 29    1d1ec077-2f48-4289-a6e2-41a7a1647afd  55850        0.752
# ...                                    ...    ...          ...
# 6097  15d58a69-72f7-4042-8b80-2e2bf3868e69  98705        0.955
# 6098  ba17925c-c491-4ef7-b150-59dd74ca5a64  98705        0.950
# 6099  f816175f-abf5-4220-ab9d-fc8ee7ba7d00  98705        0.949
# 6100  81c50c89-c8c5-4a6d-a586-efc8e65c6ff3  98705        0.949
# 6101  35aee65e-7ab3-42e1-ae4a-a4850ad314fc  98705        0.945
# 6102  8b1ac039-0e1a-4a48-b324-36e8b0e0d14b  98705        0.942
# 6103  73bbf8cd-b084-43ab-9d77-18f0750d71b9  98705        0.941
# 6104  750c03b0-3c8c-42ed-afe1-f9609711fe81  98705        0.940
# 6105  cd82b49f-2c9e-4d69-a0ff-576bccc9b82d  87169        0.970
# 6106  408bf603-8de9-4a98-b3d5-6fb7ff8b76ab  87169        0.963
# 6107  f816175f-abf5-4220-ab9d-fc8ee7ba7d00  87169        0.963
# 6108  b92222b4-e20f-4270-a5d9-2ecdf9f55896  87169        0.962
# 6109  8df6da93-2ab8-4505-95e7-512d4e007e74  87169        0.961
# 6110  a32abc24-7b68-45dd-8763-95487e647d7d  87169        0.958
# 6111  31391c29-bc76-4ac9-918f-3f7ead3be816  87169        0.957
# 6112  99fe5867-8071-4b4a-ac3b-6610be6bc2e3  87169        0.957
# 6113  139e78c5-432b-4b82-9cd3-8672fd15914d  87169        0.957
# 6114  8bce78fc-228e-4da0-8956-d1b2049221eb  87169        0.956
# 6115  2ab99612-ffa8-4f06-9a42-05028b1d0627  87169        0.955
# 6116  408bf603-8de9-4a98-b3d5-6fb7ff8b76ab  98321        0.972
# 6117  cd82b49f-2c9e-4d69-a0ff-576bccc9b82d  98321        0.971
# 6118  3348e7fa-2d0b-4cd5-b519-bd783666346e  98321        0.969
# 6119  687a7a49-0e34-43be-af1e-ac86138ec1f2  98321        0.969
# 6120  5fec0997-7631-11e4-a3cb-005056011aef  98321        0.966
# 6121  a78c0592-512e-491a-8e72-7bd8b86c6d1f  98321        0.965
# 6122  13258094-3c45-4258-8cde-a311c4a274af  98321        0.965
# 6123  5e2dcc2c-7631-11e4-a3cb-005056011aef  98321        0.964
# 6124  5f592fea-7631-11e4-a3cb-005056011aef  98321        0.964
# 6125  5fe8c254-7631-11e4-a3cb-005056011aef  98321        0.964
# 6126  5f1472e0-7631-11e4-a3cb-005056011aef  98321        0.964
#
# [6127 rows x 6 columns]

# %%
labelled_file = os.path.join(DATA_DIR, "content_api", "labelled.csv.gz")
labelled = pd.read_csv(labelled_file, 
                       compression="gzip", 
                       usecols=["base_path", "content_id", "title"])
base_cid = dict(zip(labelled.base_path, labelled.content_id))
cid_title = dict(zip(labelled.content_id, labelled.title))

# %%
results['title'] = results['cid'].map(cid_title)
results['link_title'] = results['link_cid'].map(cid_title)

# %%
results.to_csv(os.path.join(DATA_DIR, "results",\
                                 "n2v_brexit_results_orig_n2v.csv"), index=False)
