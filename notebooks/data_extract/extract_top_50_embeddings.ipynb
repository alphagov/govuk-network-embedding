# %%
import os
import pandas as pd
import numpy as np
import networkx as nx
import itertools

# %% [markdown]
# ## Directories and filenames

# %%
# os.listdir('../../data')

# %%
DATA_DIR = os.getenv("DATA_DIR")
content_api = os.path.join(DATA_DIR, "content_api")

labelled_file = os.path.join(content_api,"labelled.csv.gz")
edgefile = os.path.join(DATA_DIR, "processed_network", "edges_graphsagetest_feb_01_18_doo_min15weight_wtext.csv.gz")

# %% [markdown]
# ### 2.1 Labelled data

# %%
labelled = pd.read_csv(labelled_file, compression="gzip")
# Out:
# /Users/felisialoukou/.pyenv/versions/3.6.0/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
labelled.columns
# Out:
# Index(['base_path', 'content_id', 'description', 'document_type',
#        'first_published_at', 'locale', 'primary_publishing_organisation',
#        'publishing_app', 'title', 'body', 'combined_text', 'taxon_id',
#        'taxon_base_path', 'taxon_name', 'level1taxon', 'level2taxon',
#        'level3taxon', 'level4taxon', 'level5taxon'],
#       dtype='object')

# %%
labelled.shape, labelled[labelled.publishing_app=="publisher"].shape
# Out:
# ((302474, 19), (3563, 19))

# %% [markdown]
# ### 2.2 Training edge list, use for node id mappings

# %%
edges = pd.read_csv(edgefile, compression='gzip')

# %%
edges
# Out:
#                                                  src_node  \
# 0       /government/publications/guidance-for-dependan...
# 1                                              /visa-fees
# 2                       /entering-staying-uk/family-visas
# 3                                         /uk-family-visa
# 4                          /uk-family-visa/partner-spouse
# 5       /government/publications/application-for-uk-vi...
# 6                     /uk-family-visa/provide-information
# 7                                /apply-to-come-to-the-uk
# 8       /apply-to-come-to-the-uk/prepare-your-application
# 9                                  /visa-processing-times
# 10      /apply-to-come-to-the-uk/prepare-your-application
# 11                                             /visa-fees
# 12      /apply-to-come-to-the-uk/prepare-your-application
# 13         /log-in-register-hmrc-online-services/register
# 14                  /log-in-register-hmrc-online-services
# 15                                                      /
# 16      /self-assessment-tax-returns/who-must-send-a-t...
# 17            /self-assessment-tax-returns/sending-return
# 18                /log-in-file-self-assessment-tax-return
# 19      /log-in-file-self-assessment-tax-return/sign-i...
# 20                                                      /
# 21                  /log-in-register-hmrc-online-services
# 22           /government/organisations/hm-revenue-customs
# 23                    /topic/personal-tax/self-assessment
# 24                           /self-assessment-tax-returns
# 25      /log-in-file-self-assessment-tax-return/sign-i...
# 26      /log-in-file-self-assessment-tax-return/sign-i...
# 27                  /log-in-register-hmrc-online-services
# 28      /log-in-register-hmrc-online-services/problems...
# 29      /government/collections/hm-revenue-and-customs...
# ...                                                   ...
# 213416  /government/speeches/the-munich-security-confe...
# 213417        /email/subscriptions/new?topic_id=decisions
# 213418        /apply-for-elderly-person-bus-pass/bradford
# 213419  /drug-device-alerts/class-4-defect-information...
# 213420                        /changes-affect-tax-credits
# 213421  /expenses-and-benefits-clothing/work-out-the-v...
# 213422  /hmrc-internal-manuals/vat-supply-and-consider...
# 213423  /hmrc-internal-manuals/vat-supply-and-consider...
# 213424        /calculate-your-redundancy-pay/y/2019-02-11
# 213425  /calculate-statutory-sick-pay/y/none/yes/no/20...
# 213426  /government/publications/apply-for-a-uk-visa-i...
# 213427  /guidance/pension-schemes-work-out-your-tapere...
# 213428  /hmrc-internal-manuals/double-taxation-relief/...
# 213429                                   /exempt-vignette
# 213430  /email/subscriptions/complete?frequency=immedi...
# 213431  /guidance/aviation-security-for-passengers-and...
# 213432  /email/subscriptions/new?frequency=immediately...
# 213433  /email/subscriptions/complete?frequency=immedi...
# 213434  /email/subscriptions/new?frequency=immediately...
# 213435  /email/subscriptions/complete?frequency=immedi...
# 213436  /email/subscriptions/complete?frequency=immedi...
# 213437  /email/subscriptions/complete?frequency=immedi...
# 213438  /government/latest?departments[]=teaching-regu...
# 213439  /government/publications/teacher-misconduct-pa...
# 213440  /sold-bought-vehicle/y/no/sold-it/sold-it-to-a...
# 213441  /email/subscriptions/complete?frequency=immedi...
# 213442  /email/subscriptions/new?frequency=immediately...
# 213443           /landlord-immigration-check/y/[postcode]
# 213444  /calculate-your-redundancy-pay/y?previous_resp...
# 213445        /calculate-your-redundancy-pay/y/2019-03-31
#
#                                                 dest_node   weight  \
# 0                                              /visa-fees       66
# 1                         /find-a-visa-application-centre     1164
# 2                                         /uk-family-visa      377
# 3                          /uk-family-visa/partner-spouse    26227
# 4       /government/publications/application-for-uk-vi...     2733
# 5                     /uk-family-visa/provide-information      116
# 6                                /apply-to-come-to-the-uk       32
# 7       /apply-to-come-to-the-uk/prepare-your-application    43994
# 8                                  /visa-processing-times     4669
# 9       /apply-to-come-to-the-uk/prepare-your-application     1220
# 10                                             /visa-fees     4898
# 11      /apply-to-come-to-the-uk/prepare-your-application     1023
# 12                        /find-a-visa-application-centre      675
# 13                  /log-in-register-hmrc-online-services   230917
# 14                                                      /    66712
# 15      /self-assessment-tax-returns/who-must-send-a-t...      666
# 16            /self-assessment-tax-returns/sending-return    41470
# 17                /log-in-file-self-assessment-tax-return    86105
# 18      /log-in-file-self-assessment-tax-return/sign-i...  3752972
# 19                                                      /    39641
# 20                  /log-in-register-hmrc-online-services   162104
# 21           /government/organisations/hm-revenue-customs   310711
# 22                    /topic/personal-tax/self-assessment   653021
# 23                           /self-assessment-tax-returns   246496
# 24      /self-assessment-tax-returns/who-must-send-a-t...    56106
# 25                /log-in-file-self-assessment-tax-return    68822
# 26                  /log-in-register-hmrc-online-services    19836
# 27      /log-in-register-hmrc-online-services/problems...    73941
# 28      /government/collections/hm-revenue-and-customs...     6083
# 29      /government/publications/self-assessment-servi...     1373
# ...                                                   ...      ...
# 213416                          /government/announcements       15
# 213417  /email/subscriptions/new?frequency=immediately...       35
# 213418                      /state-pension-age/y/bus_pass       15
# 213419  /health-and-social-care/medicines-medical-devi...       15
# 213420  /guidance/government-gateway-replacement-servi...       26
# 213421  /guidance/job-expenses-for-uniforms-work-cloth...       16
# 213422  /hmrc-internal-manuals/vat-supply-and-consider...       16
# 213423  /hmrc-internal-manuals/vat-supply-and-consider...       15
# 213424     /calculate-your-redundancy-pay/y/2019-02-11/44       17
# 213425  /calculate-statutory-sick-pay/y/none/yes/no/20...       20
# 213426  /government/publications/apply-for-a-uk-visa-i...       18
# 213427                                    /tax-on-pension       19
# 213428  /hmrc-internal-manuals/double-taxation-relief/...       15
# 213429            /check-uk-visa/y/afghanistan/diplomatic       17
# 213430  /email/subscriptions/new?frequency=immediately...       25
# 213431  /government/publications/aviation-security-if-...       16
# 213432  /email/subscriptions/complete?frequency=immedi...       20
# 213433  /email/subscriptions/new?frequency=immediately...       20
# 213434  /email/subscriptions/complete?frequency=immedi...       20
# 213435  /email/subscriptions/new?frequency=immediately...       20
# 213436  /email/subscriptions/new?frequency=immediately...       31
# 213437  /email/subscriptions/new?frequency=immediately...       25
# 213438  /government/publications/teacher-misconduct-pa...       20
# 213439  /government/latest?departments[]=teaching-regu...       15
# 213440  /government/news/dont-buy-a-vehicle-without-a-...       15
# 213441  /email/subscriptions/new?frequency=immediately...       33
# 213442        /email/subscriptions/new?topic_id=decisions       28
# 213443                        /landlord-immigration-check       17
# 213444        /calculate-your-redundancy-pay/y/2019-03-31       25
# 213445  /calculate-your-redundancy-pay/y?previous_resp...       23
#
#                                      src_cid  \
# 0       5ef7560d-7631-11e4-a3cb-005056011aef
# 1       1e333395-5dd5-4452-96a3-fbe939928761
# 2       d612c61e-22f4-4922-8bb2-b04b9202126e
# 3       305acc88-488e-44ec-8e5a-1a5de7819ba9
# 4       305acc88-488e-44ec-8e5a-1a5de7819ba9
# 5       5ef421be-7631-11e4-a3cb-005056011aef
# 6       305acc88-488e-44ec-8e5a-1a5de7819ba9
# 7       76698ffe-70ab-4fda-be0d-755234f6d340
# 8       76698ffe-70ab-4fda-be0d-755234f6d340
# 9       72ed754c-4c82-415f-914a-ab6760454cb4
# 10      76698ffe-70ab-4fda-be0d-755234f6d340
# 11      1e333395-5dd5-4452-96a3-fbe939928761
# 12      76698ffe-70ab-4fda-be0d-755234f6d340
# 13      632d1ae0-0340-4a23-87b0-595bb596e5f4
# 14      632d1ae0-0340-4a23-87b0-595bb596e5f4
# 15      f3bbdec2-0e62-4520-a7fd-6ffd5d36e03a
# 16      f29ca4a8-8ed9-4b0f-bb6a-11e373095dee
# 17      f29ca4a8-8ed9-4b0f-bb6a-11e373095dee
# 18      6a2bf66e-2313-4204-afd5-9940de5e1d66
# 19      c9a1f266-d819-44e5-82f7-53b347887727
# 20      f3bbdec2-0e62-4520-a7fd-6ffd5d36e03a
# 21      632d1ae0-0340-4a23-87b0-595bb596e5f4
# 22      6667cce2-e809-4e21-ae09-cb0bdc1ddda3
# 23      7beb97b6-75c9-4aa7-86be-a733ab3a21aa
# 24      f29ca4a8-8ed9-4b0f-bb6a-11e373095dee
# 25      c9a1f266-d819-44e5-82f7-53b347887727
# 26      c9a1f266-d819-44e5-82f7-53b347887727
# 27      632d1ae0-0340-4a23-87b0-595bb596e5f4
# 28      632d1ae0-0340-4a23-87b0-595bb596e5f4
# 29      4144624e-fe0c-4e1e-82dd-43eb632d9d03
# ...                                      ...
# 213416  6c52a310-3756-499a-82f7-53553701d2f2
# 213417  1773511a-b3c9-4f37-8692-91a718d5b6ae
# 
# ...                                      ...     ...     ...
# 213416  88936763-df8a-441f-8b96-9ea0dc0758a1   44979   52390
# 213417  1773511a-b3c9-4f37-8692-91a718d5b6ae   33540   45326
# 213418  cdca2cab-da55-4184-abb3-af27764dd756   56169   25860
# 213419  51bbdf23-292a-4b74-8a66-f7db6b93b163   11808   38610
# 213420  9c8b79a9-204b-4558-aa45-fa2fc56e3891    4164    7208
# 213421  5a5fd551-778d-4c2c-ae58-3c3507fecd2b   43425   65618
# 213422  0065d8ad-55f7-5bc2-8fdd-fb1edad7d9bf   28565   55532
# 213423  cb690b0a-121a-5564-a0b3-a118e0c1383e   55532   18959
# 213424  3b45f914-07a3-468d-b257-efbd2d25a08c    5722   10748
# 213425  c3ecdaf0-5d37-45d0-bded-d9f1095b60d1   27972   18856
# 213426  5f10e8d7-7631-11e4-a3cb-005056011aef   32996   25160
# 213427  60412ad2-e0a7-4000-8517-41e5460419e6   24763   62083
# 213428  404f67a9-39a2-5231-a8b0-031e82481c67   11639   52129
# 213429  34b852ce-9045-4431-9a16-6609d307cdb7   25600   13710
# 213430  1773511a-b3c9-4f37-8692-91a718d5b6ae   37718   37941
# 213431  e0352b8a-09cc-4f78-b72f-d8c795c52901   64485   45579
# 213432  1773511a-b3c9-4f37-8692-91a718d5b6ae   16765   43167
# 213433  1773511a-b3c9-4f37-8692-91a718d5b6ae   43167   16765
# 213434  1773511a-b3c9-4f37-8692-91a718d5b6ae    1724   65941
# 213435  1773511a-b3c9-4f37-8692-91a718d5b6ae   65941    1724
# 213436  1773511a-b3c9-4f37-8692-91a718d5b6ae   21386   13778
# 213437  1773511a-b3c9-4f37-8692-91a718d5b6ae   62144    6789
# 213438  f373ade1-a86e-495e-aa0c-00973750625a   42805   29182
# 213439  4672b1ff-f147-4d49-a5f4-4959588da5a8   29182   42805
# 213440  43134131-7005-441a-b23b-01a08c9aa23f   35863    2664
# 213441  1773511a-b3c9-4f37-8692-91a718d5b6ae   44425   56322
# 213442  1773511a-b3c9-4f37-8692-91a718d5b6ae   45326   33540
# 213443  a6c2dbbb-a26e-4cc5-a244-48ef45523269    9365   58775
# 213444  3b45f914-07a3-468d-b257-efbd2d25a08c   18324   58263
# 213445  3b45f914-07a3-468d-b257-efbd2d25a08c   58263   18324
#
# [213446 rows x 7 columns]

# %% [markdown]
# ### 2.4 Read in top GOV.UK pages for February 2019
# Set up a subsmaple to predict for

# %%
top = pd.read_csv(os.path.join(DATA_DIR, "top-pages-govuk-feb19.tsv"), sep='\t', usecols=['Page', 'Page Views'])

# %%
top['Page'] = top['Page'].map(lambda x: x.replace("https://www.integration.publishing.service.gov.uk",""))
top['Page Views'] = top['Page Views'].map(lambda x: x.replace(',', ''))
top['Page Views'] = top['Page Views'].astype("float")

# %% [markdown]
# #### Check which top pages are included in the `labelled` dataset.

# %%
top = top[top.Page.isin(labelled.base_path.values)]

# %%
top.head()
# Out:
#                                     Page  Page Views
# 2              /sign-in-universal-credit   8221833.0
# 3  /log-in-register-hmrc-online-services   6564918.0
# 4                   /sold-bought-vehicle   4722768.0
# 5                           /vehicle-tax   4670761.0
# 6                     /check-mot-history   4666636.0

# %% [markdown]
# ## 3. Initialize train/test generator data

# %%
labelled_cid = set(labelled.content_id.values)
len(labelled_cid)
# Out:
# 206038

# %%
cid_base = dict(zip(labelled.content_id, labelled.base_path))
base_cid = dict(zip(labelled.base_path, labelled.content_id))

# %%
# cid_pairs = []
# basepath_pairs = []
# for v,w in itertools.product([list(mainstream)[1]],labelled_cid):
#     if v!=w:
#         cid_pairs.append((v,w))
#         basepath_pairs.append((cid_base[v], cid_base[w]))
# len(cid_pairs), len(basepath_pairs)

# %% [markdown]
# ### 3.1 Set up dataframe with top 50 pages

# %%
type(top["Page Views"].iloc[0])
# Out:
# numpy.float64

# %%
top.sort_values("Page Views", ascending=False)[0:10]
# Out:
#                                        Page  Page Views
# 2                 /sign-in-universal-credit   8221833.0
# 3     /log-in-register-hmrc-online-services   6564918.0
# 4                      /sold-bought-vehicle   4722768.0
# 5                              /vehicle-tax   4670761.0
# 6                        /check-mot-history   4666636.0
# 8   /log-in-file-self-assessment-tax-return   3968998.0
# 10                       /state-pension-age   3792312.0
# 11                       /check-vehicle-tax   3769755.0
# 12         /get-information-about-a-company   3632017.0
# 13            /pay-self-assessment-tax-bill   3631506.0

# %%
### top base_paths to content_ids
top['content_id'] = top['Page'].map(base_cid)
top_50_ids = top.sort_values("Page Views", ascending=False)['content_id'][0:50].values

# %%
top

# %%
cid_pairs = []
basepath_pairs = []
for v,w in itertools.product(top_50_ids, labelled_cid):
    if v!=w:
        cid_pairs.append((v,w))
        basepath_pairs.append((cid_base[v], cid_base[w]))
len(cid_pairs), len(basepath_pairs)
# Out:
# (10301850, 10301850)

# %% [markdown]
# ### 3.2 Set up test set for prediction, top pages against the entirety of `labelled`

# %%
predict_test = pd.DataFrame({'src_cid':[s for s,_ in cid_pairs], 
                             'dest_cid':[t for _,t in cid_pairs],
                             'src_node':[s for s,_ in basepath_pairs], 
                             'dest_node':[t for _,t in basepath_pairs],
                              })

# %%
predict_test.head()
# Out:
#                                 src_cid                              dest_cid  \
# 0  b220a437-0d51-4390-9993-63345d0c83ad  a4481bd0-8986-4a85-a445-44f10f715349
# 1  b220a437-0d51-4390-9993-63345d0c83ad  953e4007-b6ce-4d8d-aa20-05a34c3e3bf4
# 2  b220a437-0d51-4390-9993-63345d0c83ad  44997587-823b-4663-be55-d5636e406828
# 3  b220a437-0d51-4390-9993-63345d0c83ad  c4b30e72-0311-466f-87a5-35900fb69dda
# 4  b220a437-0d51-4390-9993-63345d0c83ad  4ced5048-608f-4729-96a2-9b1cb12cea19
#
#                     src_node  \
# 0  /sign-in-universal-credit
# 1  /sign-in-universal-credit
# 2  /sign-in-universal-credit
# 3  /sign-in-universal-credit
# 4  /sign-in-universal-credit
#
#                                            dest_node
# 0  /employment-tribunal-decisions/mr-m-gurney-v-b...
# 1  /government/news/moj-unit-in-crackdown-on-rogu...
# 2  /aaib-reports/piper-pa-38-112-tomahawk-g-bjur-...
# 3  /guidance/veterinary-medicines-summary-of-prod...
# 4  /government/statistics/uk-house-price-index-oc...

# %% [markdown]
# #### *TODO:* Base node_ids on base_paths, not content_id

# %%
predict_test.columns
# Out:
# Index(['src_cid', 'dest_cid', 'src_node', 'dest_node'], dtype='object')

# %%
node_id = dict(zip(edges.src_node, edges.source))
for node,nid in zip(edges.dest_node, edges.target):
    if node not in node_id.keys():
        node_id[node] = nid

# %%
len(node_id)
# Out:
# 66619

# %%
max_node_id = max(edges.source.max(),edges.target.max()) + 1
for node in set(list(predict_test.src_node) + list(predict_test.dest_node.values)):
    if node not in node_id.keys():
        node_id[node] = max_node_id
        max_node_id+=1

# %%
max_node_id
# Out:
# 255643

# %%
predict_test['source'] = predict_test['src_node'].map(node_id)
predict_test['target'] = predict_test['dest_node'].map(node_id)

# %%
predict_test['label'] = "go_to"

# %% [markdown]
# ### 3.3 Compute embedding vectors

# %%
cid_texts = list(zip(labelled.content_id, labelled.combined_text))

# %%
len(cid_texts)
# Out:
# 302474

# %%
labelled.shape
# Out:
# (302474, 19)

# %%
len(cid_texts)
# Out:
# 302474

# %%
cids = [cid for cid, _ in cid_texts]
texts = [" ".join([token.strip() for token in text.split(" ")[0:300]]) for _, text in cid_texts]

# %%
texts[0]
# Out:
# 'reims cessna fa152 g-bgxz 27 may 1988   reims cessna fa152 g bgxz download report: reims cessna fa152 g bgxz 09 88.pdf (76.87 kb)'

# %%
import tensorflow as tf
import tensorflow_hub as hub
module_url = "https://tfhub.dev/google/universal-sentence-encoder/2"
tf.logging.set_verbosity(tf.logging.DEBUG)
embed = hub.Module(module_url)

with tf.Session() as session:
    session.run([tf.global_variables_initializer(), tf.tables_initializer()])
    embeddings = session.run(embed(texts))
# Out:
# DEBUG:tensorflow:Initialize variable module_1/Embeddings_en/sharded_0:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Embeddings_en/sharded_0
# DEBUG:tensorflow:Initialize variable module_1/Embeddings_en/sharded_1:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Embeddings_en/sharded_1
# DEBUG:tensorflow:Initialize variable module_1/Embeddings_en/sharded_10:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Embeddings_en/sharded_10
# DEBUG:tensorflow:Initialize variable module_1/Embeddings_en/sharded_11:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Embeddings_en/sharded_11
# DEBUG:tensorflow:Initialize variable module_1/Embeddings_en/sharded_12:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Embeddings_en/sharded_12
# DEBUG:tensorflow:Initialize variable module_1/Embeddings_en/sharded_13:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Embeddings_en/sharded_13
# DEBUG:tensorflow:Initialize variable module_1/Embeddings_en/sharded_14:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Embeddings_en/sharded_14
# DEBUG:tensorflow:Initialize variable module_1/Embeddings_en/sharded_15:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Embeddings_en/sharded_15
# DEBUG:tensorflow:Initialize variable module_1/Embeddings_en/sharded_16:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Embeddings_en/sharded_16
# DEBUG:tensorflow:Initialize variable module_1/Embeddings_en/sharded_2:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Embeddings_en/sharded_2
# DEBUG:tensorflow:Initialize variable module_1/Embeddings_en/sharded_3:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Embeddings_en/sharded_3
# DEBUG:tensorflow:Initialize variable module_1/Embeddings_en/sharded_4:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Embeddings_en/sharded_4
# DEBUG:tensorflow:Initialize variable module_1/Embeddings_en/sharded_5:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Embeddings_en/sharded_5
# DEBUG:tensorflow:Initialize variable module_1/Embeddings_en/sharded_6:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Embeddings_en/sharded_6
# DEBUG:tensorflow:Initialize variable module_1/Embeddings_en/sharded_7:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Embeddings_en/sharded_7
# DEBUG:tensorflow:Initialize variable module_1/Embeddings_en/sharded_8:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Embeddings_en/sharded_8
# DEBUG:tensorflow:Initialize variable module_1/Embeddings_en/sharded_9:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Embeddings_en/sharded_9
# DEBUG:tensorflow:Initialize variable module_1/Encoder_en/DNN/ResidualHidden_0/weights:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Encoder_en/DNN/ResidualHidden_0/weights
# DEBUG:tensorflow:Initialize variable module_1/Encoder_en/DNN/ResidualHidden_1/weights:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Encoder_en/DNN/ResidualHidden_1/weights
# DEBUG:tensorflow:Initialize variable module_1/Encoder_en/DNN/ResidualHidden_2/weights:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Encoder_en/DNN/ResidualHidden_2/weights
# DEBUG:tensorflow:Initialize variable module_1/Encoder_en/DNN/ResidualHidden_3/projection:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Encoder_en/DNN/ResidualHidden_3/projection
# DEBUG:tensorflow:Initialize variable module_1/Encoder_en/DNN/ResidualHidden_3/weights:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with Encoder_en/DNN/ResidualHidden_3/weights
# DEBUG:tensorflow:Initialize variable module_1/SHARED_RANK_ANSWER/response_encoder_0/tanh_layer_0/bias:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with SHARED_RANK_ANSWER/response_encoder_0/tanh_layer_0/bias
# DEBUG:tensorflow:Initialize variable module_1/SHARED_RANK_ANSWER/response_encoder_0/tanh_layer_0/weights:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with SHARED_RANK_ANSWER/response_encoder_0/tanh_layer_0/weights
# DEBUG:tensorflow:Initialize variable module_1/SHARED_RANK_ANSWER/response_encoder_0/tanh_layer_1/bias:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with SHARED_RANK_ANSWER/response_encoder_0/tanh_layer_1/bias
# DEBUG:tensorflow:Initialize variable module_1/SHARED_RANK_ANSWER/response_encoder_0/tanh_layer_1/weights:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with SHARED_RANK_ANSWER/response_encoder_0/tanh_layer_1/weights
# DEBUG:tensorflow:Initialize variable module_1/SHARED_RANK_ANSWER/response_encoder_0/tanh_layer_2/bias:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with SHARED_RANK_ANSWER/response_encoder_0/tanh_layer_2/bias
# DEBUG:tensorflow:Initialize variable module_1/SHARED_RANK_ANSWER/response_encoder_0/tanh_layer_2/weights:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with SHARED_RANK_ANSWER/response_encoder_0/tanh_layer_2/weights
# DEBUG:tensorflow:Initialize variable module_1/SNLI/Classifier/LinearLayer/bias:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with SNLI/Classifier/LinearLayer/bias
# DEBUG:tensorflow:Initialize variable module_1/SNLI/Classifier/LinearLayer/weights:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with SNLI/Classifier/LinearLayer/weights
# DEBUG:tensorflow:Initialize variable module_1/SNLI/Classifier/tanh_layer_0/bias:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with SNLI/Classifier/tanh_layer_0/bias
# DEBUG:tensorflow:Initialize variable module_1/SNLI/Classifier/tanh_layer_0/weights:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with SNLI/Classifier/tanh_layer_0/weights
# DEBUG:tensorflow:Initialize variable module_1/global_step:0 from checkpoint b'/var/folders/9s/cvtxyh055w94_xfm_cwjrngh000121/T/tfhub_modules/1fb57c3ffe1a38479233ee9853ddd7a8ac8a8c47/variables/variables' with global_step
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore

# %%
len(embeddings)
# Out:
# 302474

# %% [markdown]
# ### Set `node_data` from vectors
# Index matches up to `node_id` in edge list dataframe

# %%
cid_embs = dict(zip(cids, embeddings))

# %%
nid_cid = dict(zip(predict_test['source'], predict_test['src_cid']))
for nid,cid in zip(predict_test['target'], predict_test['dest_cid']):
    if nid not in nid_cid.keys():
        nid_cid[nid] = cid

# %%
rowlist = []
index = []
for nid in set(list(predict_test['source']) + list(predict_test['target'])):
    row_dict = {}
    row_dict["content_id"] = nid_cid[nid]
    for i,emb in enumerate(cid_embs[nid_cid[nid]]):
        row_dict[i] = emb
    rowlist.append(row_dict)  
    index.append(nid)
node_data = pd.DataFrame(rowlist, index=index)

# %%
node_data
# Out:
#                                   content_id         0         1         2  \
# 0       80f7a69c-5cdc-4bd5-a16c-15d669ba2cc5  0.014993  0.024639  0.058578
# 2       5ef9b7da-7631-11e4-a3cb-005056011aef -0.002469 -0.009080  0.014424
# 7       763fd665-f01d-469a-88ad-ccc434e5ac6d -0.042398 -0.042146  0.045832
# 9       2e7ccd7e-7294-43cf-9576-145e06dd9b3d  0.007414 -0.020822  0.054993
# 12      30ac0189-560d-43e4-9f19-7a10a7b4d280 -0.054434  0.029956  0.041951
# 14      1acc164f-e3cd-4d18-96e0-8c2c892e20b0  0.026161  0.053684  0.028029
# 18      5d8c6b11-7631-11e4-a3cb-005056011aef  0.014118  0.036567  0.041868
# 19      5efa14bb-7631-11e4-a3cb-005056011aef  0.017697 -0.022237  0.040489
# 23      874a177d-a5a7-41d9-8302-c087d13be958 -0.013949 -0.060453  0.036274
# 24      9f499637-069e-4810-ac65-2430782a5ec0 -0.020951  0.003924  0.041680
# 26      5e155b7d-7631-11e4-a3cb-005056011aef -0.059186 -0.025548  0.053299
# 28      50148125-71ce-4ca3-9339-984b494267b7  0.010581  0.025000  0.041321
# 31      47265f00-57ed-4b57-abce-364435d5b763 -0.055725  0.024588  0.040114
# 37      e5b05b4b-7c9f-4aad-9325-1b8f8a9f0eeb -0.024992 -0.053118  0.030832
# 39      6ad2b97b-abe6-451c-9cf0-9b7217768ac0 -0.053887  0.017579  0.052117
# 43      388f10d4-1aac-40e4-b89a-32928ac2c678  0.045690 -0.059217  0.015242
# 44      6045eb56-f9b4-456b-b1f2-2897fd242eab -0.054124  0.031498 -0.009877
# 51      5fe942ce-7631-11e4-a3cb-005056011aef -0.023320 -0.047611  0.031305
# 55      0acd1564-81dc-4456-a0cf-887c0bc33e23 -0.025593 -0.011651  0.046003
# 255616  0.055725 -0.000427 -0.046623
# 255617  0.055350  0.041589 -0.059523
# 255618 -0.029139  0.024800 -0.059948
# 255619  0.055372 -0.018914 -0.055517
# 255620 -0.042871  0.014806 -0.064282
# 255621  0.001203  0.027729 -0.047953
# 255622  0.041146  0.010389 -0.049425
# 255623 -0.047076 -0.043967 -0.003348
# 255624 -0.022734 -0.046748 -0.051416
# 255625 -0.023471 -0.007192 -0.059455
# 255626 -0.030420  0.021296 -0.046052
# 255627 -0.028033  0.012160  0.003952
# 255628 -0.037272 -0.008933  0.032799
# 255629 -0.040664  0.033044 -0.023551
# 255630 -0.038293  0.019306 -0.057444
# 255631 -0.049239  0.035784 -0.054966
# 255632 -0.036420 -0.022513 -0.011637
# 255633  0.058916 -0.031846  0.005881
# 255634 -0.012936  0.034623 -0.051570
# 255635  0.001969 -0.026514 -0.050921
# 255636 -0.023541  0.018826 -0.063714
# 255637 -0.031809 -0.009819  0.018337
# 255638 -0.059800  0.021171 -0.064140
# 255639 -0.001353 -0.068532  0.051293
# 255640 -0.041408  0.040478 -0.062683
# 255641  0.059613 -0.026931 -0.050427
# 255642 -0.058290 -0.033259 -0.038815
#
# [206038 rows x 513 columns]

# %% [markdown]
# ## 4. Save to file

# %%
predict_test.shape, node_data.shape
# Out:
# ((10301850, 7), (206038, 513))

# %%
predict_test.head()
# Out:
#                                 src_cid                              dest_cid  \
# 0  b220a437-0d51-4390-9993-63345d0c83ad  a4481bd0-8986-4a85-a445-44f10f715349
# 1  b220a437-0d51-4390-9993-63345d0c83ad  953e4007-b6ce-4d8d-aa20-05a34c3e3bf4
# 2  b220a437-0d51-4390-9993-63345d0c83ad  44997587-823b-4663-be55-d5636e406828
# 3  b220a437-0d51-4390-9993-63345d0c83ad  c4b30e72-0311-466f-87a5-35900fb69dda
# 4  b220a437-0d51-4390-9993-63345d0c83ad  4ced5048-608f-4729-96a2-9b1cb12cea19
#
#                     src_node  \
# 0  /sign-in-universal-credit
# 1  /sign-in-universal-credit
# 2  /sign-in-universal-credit
# 3  /sign-in-universal-credit
# 4  /sign-in-universal-credit
#
#                                            dest_node  source  target  label
# 0  /employment-tribunal-decisions/mr-m-gurney-v-b...    5947  255142  go_to
# 1  /government/news/moj-unit-in-crackdown-on-rogu...    5947  121560  go_to
# 2  /aaib-reports/piper-pa-38-112-tomahawk-g-bjur-...    5947  137263  go_to
# 3  /guidance/veterinary-medicines-summary-of-prod...    5947  138723  go_to
# 4  /government/statistics/uk-house-price-index-oc...    5947  229385  go_to

# %%
predict_test.shape
# Out:
# ((10301850, 7), 14821226)

# %%
predict_test.target.max()
# Out:
# 255642

# %%
PREDICT_DIR = os.path.join(DATA_DIR, "predict_network")
predict_file = os.path.join(PREDICT_DIR, "predict_top50_vs_all.csv.gz")
node_data_file = os.path.join(PREDICT_DIR, "predict_top50_vs_all_node_data_embs_300.csv.gz")

# %%
predict_test.to_csv(predict_file, index=False, compression="gzip")
node_data.to_csv(node_data_file, compression="gzip")

# %%
# # Double check
# n2 = pd.read_csv(node_data_file, index_col=0)
# n2.head()
