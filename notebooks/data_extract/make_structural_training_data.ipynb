# %%
import os
import pandas as pd
import numpy as np
import gzip
import ijson
from ast import literal_eval
import networkx as nx
import itertools
import re

# %% [markdown]
# ## Directories

# %%
DATA_DIR = os.getenv("DATA_DIR")
PREDICT_DIR = os.path.join(DATA_DIR, "predict_network")
content_api = os.path.join(DATA_DIR, "content_api")
sub_content_api = os.path.join(content_api,"all_dates")
# api_links_file = os.path.join(content_api,"07-02-19", "content_api_links.csv.gz")
labelled_file = os.path.join(content_api,"labelled.csv.gz")

# %% [markdown]
# ## Initialized labelled/content

# %%
labelled = pd.read_csv(labelled_file, compression="gzip", usecols=['base_path', 'content_id', 'title'])

# %%
labelled.drop_duplicates("content_id", inplace=True)

# %%
len(labelled.base_path)
# Out:
# 206038

# %%
labelled[labelled.base_path=="/sign-in-universal-credit"]
# Out:
#                         base_path                            content_id  \
# 272249  /sign-in-universal-credit  b220a437-0d51-4390-9993-63345d0c83ad
#
#                                            title
# 272249  sign in to your universal credit account

# %% [markdown]
# ## Read in links data

# %%
api_links_files = [os.path.join(sub_content_api, f) for f in os.listdir(sub_content_api) if "api_links" in f]
api_links_files
# Out:
# ['/Users/felisialoukou/Documents/govuk-network-embedding/data/content_api/all_dates/missing_urls_240219_content_api_links.csv.gz',
#  '/Users/felisialoukou/Documents/govuk-network-embedding/data/content_api/all_dates/labelled2_content_api_links.csv.gz',
#  '/Users/felisialoukou/Documents/govuk-network-embedding/data/content_api/all_dates/pt01of9_content_api_links.csv.gz',
#  '/Users/felisialoukou/Documents/govuk-network-embedding/data/content_api/all_dates/content_api_links07.csv.gz',
#  '/Users/felisialoukou/Documents/govuk-network-embedding/data/content_api/all_dates/content_api_links_remote.csv.gz',
#  '/Users/felisialoukou/Documents/govuk-network-embedding/data/content_api/all_dates/content_api_links_22.csv.gz',
#  '/Users/felisialoukou/Documents/govuk-network-embedding/data/content_api/all_dates/labelled1_content_api_links.csv.gz',
#  '/Users/felisialoukou/Documents/govuk-network-embedding/data/content_api/all_dates/pt02of9_content_api_links.csv.gz',
#  '/Users/felisialoukou/Documents/govuk-network-embedding/data/content_api/all_dates/content_api_links.csv.gz']

# %%
links = pd.concat([pd.read_csv(f, compression="gzip") for f in api_links_files], ignore_index=True)
links.drop_duplicates("url", inplace=True)
links.shape, links.columns
# Out:
# ((231145, 7),
#  Index(['url', 'embedded_links', 'related_links', 'collection_links', 'num_rel',
#         'num_emb', 'num_coll'],
#        dtype='object'))

# %%
missing_urls = set(labelled.base_path).difference(set(links.url))
print(len(missing_urls))
# Out:
# 4

# %%
with gzip.open(os.path.join(sub_content_api, "missing_urls_250219.csv.gz"), "wt") as w:
    w.write("Node\n")
    for missing in missing_urls:
        w.write("{}\n".format(missing))

# %%
link_types = ['embedded_links',  'collection_links', 'related_links']

def lit_eval(x):
    return [l.strip() for l in re.sub("\[|\]|'","",x).split(",")]

for ltype in link_types:
    print(ltype)
    links[ltype] = links[ltype].map(lambda x: lit_eval(x))
# Out:
# embedded_links
# collection_links
# related_links

# %%
links[links.url=="/sign-in-universal-credit"].related_links.values[0][1]
# Out:
# '/apply-universal-credit'

# %%
links.columns.get_loc("embedded_links")
# Out:
# 1

# %%
adj_list = []
for tup in links.itertuples(index=False):
    for ltype in link_types:
        tup_ind = links.columns.get_loc(ltype)
        if len(tup[tup_ind]) > 0:
            for dest in tup[tup_ind]:
#                 if dest in labelled.base_path.values:
                adj_list.append((tup.url, dest, ltype))

# %%
# ((231145, 7), 887717)
links.shape, len(adj_list)
# Out:
# ((231145, 7), 887717)

# %%
graph = nx.DiGraph()

# %%
for s,d,t in adj_list:
    graph.add_edge(s,d,link_type=t)

# %%
nx.info(graph)
# Out:
# 'Name: \nType: DiGraph\nNumber of nodes: 437808\nNumber of edges: 512879\nAverage in degree:   1.1715\nAverage out degree:   1.1715'

# %%
base_cid = dict(zip(labelled.base_path, labelled.content_id))

# %%
rowlist = []
for s,d,t in adj_list:
    row = {'src_node':s,
    'dest_node': d,
    'link_type': t,
    'src_cid': base_cid[s] if s in base_cid.keys() else np.nan,
    'dest_cid': base_cid[d] if d in base_cid.keys() else np.nan}
    rowlist.append(row)

# %%
df_structural = pd.DataFrame(rowlist)

# %%
df_structural.shape, df_structural.dropna(subset=["dest_cid","src_cid"]).shape
# Out:
# ((887717, 5), (62660, 5))

# %%
structural_file = os.path.join(content_api, "structural_training_data_no_node_id.csv.gz")
df_struct_filter = df_structural.dropna(subset=["dest_cid","src_cid"]).copy(deep=True)
df_struct_filter.to_csv(structural_file, index=False, compression="gzip")

# %% [markdown]
# ## Merge structural with functional data

# %%
edgefile = os.path.join(DATA_DIR, "processed_network", "edges_graphsagetest_feb_01_18_doo_min15weight_wtext.csv.gz")
edges = pd.read_csv(edgefile, compression="gzip")
edges.head()
# Out:
#                                             src_node  \
# 0  /government/publications/guidance-for-dependan...
# 1                                         /visa-fees
# 2                  /entering-staying-uk/family-visas
# 3                                    /uk-family-visa
# 4                     /uk-family-visa/partner-spouse
#
#                                            dest_node  weight  \
# 0                                         /visa-fees      66
# 1                    /find-a-visa-application-centre    1164
# 2                                    /uk-family-visa     377
# 3                     /uk-family-visa/partner-spouse   26227
# 4  /government/publications/application-for-uk-vi...    2733
#
#                                 src_cid                              dest_cid  \
# 0  5ef7560d-7631-11e4-a3cb-005056011aef  1e333395-5dd5-4452-96a3-fbe939928761
# 1  1e333395-5dd5-4452-96a3-fbe939928761  aa055bd6-fde1-4471-8ac2-ac86241b4898
# 2  d612c61e-22f4-4922-8bb2-b04b9202126e  305acc88-488e-44ec-8e5a-1a5de7819ba9
# 3  305acc88-488e-44ec-8e5a-1a5de7819ba9  305acc88-488e-44ec-8e5a-1a5de7819ba9
# 4  305acc88-488e-44ec-8e5a-1a5de7819ba9  5ef421be-7631-11e4-a3cb-005056011aef
#
#    source  target
# 0   33265   58314
# 1   58314   12343
# 2   23720   25053
# 3   25053   14044
# 4   14044   33797

# %%
node_id = dict(zip(edges.src_node, edges.source))
for node,nid in zip(edges.dest_node, edges.target):
    if node not in node_id.keys():
        node_id[node] = nid

# %%
df_struct_filter['source'] = df_struct_filter['src_node'].map(lambda x: node_id[x] if x in node_id.keys() else -1)
df_struct_filter['target'] = df_struct_filter['dest_node'].map(lambda x: node_id[x] if x in node_id.keys() else -1)

# %%
df_struct_filter.head(2)
# Out:
#                                  dest_cid  \
# 194  5ef78617-7631-11e4-a3cb-005056011aef
# 195  5ef78888-7631-11e4-a3cb-005056011aef
#
#                                              dest_node         link_type  \
# 194  /government/publications/transxchange-examples...  collection_links
# 195     /government/publications/transxchange-overview  collection_links
#
#                                   src_cid  \
# 194  5ef7544d-7631-11e4-a3cb-005056011aef
# 195  5ef7544d-7631-11e4-a3cb-005056011aef
#
#                                  src_node  source  target
# 194  /government/collections/transxchange      -1      -1
# 195  /government/collections/transxchange      -1      -1

# %%
df_struct_filter.shape
# Out:
# (62660, 7)

# %%
# df_struct_filter[df_struct_filter.source==-1].src_node
# df_struct_filter[df_struct_filter.target==-1].dest_node
# df_struct_filter.dest_node
def compute_coverage(src_node, dest_node, miss_src, miss_dest):
    ### Number of unique nodes
    unique_nodes = set(list(src_node) + list(dest_node))
    print(len(unique_nodes))
    missing_nodes = list(set(miss_src))
    missing_nodes.extend(list(set(miss_dest)))
    print(len(missing_nodes))
    print("\n {} nodes in funct, but not in struct".format(len(set(node_id.keys()).difference(unique_nodes))),"\n",
    "{} nodes both in funct and struct data".format(len(set(node_id.keys()).intersection(unique_nodes))),"\n",
    "{} nodes in struct, but not in funct".format(len(set(unique_nodes).difference(node_id.keys()))))

# %%
compute_coverage(df_struct_filter.src_node, 
                 df_struct_filter.dest_node, 
                 df_struct_filter[df_struct_filter.source==-1].src_node, 
                 df_struct_filter[df_struct_filter.target==-1].dest_node)
# Out:
# 52323
# 41416
#
#  55541 nodes in funct, but not in struct
#  11078 nodes both in funct and struct data
#  41245 nodes in struct, but not in funct

# %% [markdown]
#      55541 nodes in funct, but not in struct
#      11078 nodes both in funct and struct data
#      41245 nodes in struct, but not in funct

# %%
max_node = max(node_id.values())+1
for node in missing_nodes:
    if node not in node_id.keys():
        node_id[node] = max_node
        max_node+=1

# %%
df_struct_filter['source'] = df_struct_filter['src_node'].map(lambda x: node_id[x] if x in node_id.keys() else -1)
df_struct_filter['target'] = df_struct_filter['dest_node'].map(lambda x: node_id[x] if x in node_id.keys() else -1)

# %%
compute_coverage(df_struct_filter.src_node, 
                 df_struct_filter.dest_node, 
                 df_struct_filter[df_struct_filter.source==-1].src_node, 
                 df_struct_filter[df_struct_filter.target==-1].dest_node)
# Out:
# 52323
# 0
#
#  55541 nodes in funct, but not in struct
#  52323 nodes both in funct and struct data
#  0 nodes in struct, but not in funct

# %%
df_struct_filter.shape
# Out:
# (62660, 7)

# %%
merged_edges = pd.concat([edges, df_struct_filter.drop('link_type', axis=1)], ignore_index=True, sort=True)

# %%
edges.shape, merged_edges.shape
# Out:
# ((213446, 7), (276106, 7))

# %%
### Figure out whicj

# %%
merged_edges['edge-id'] = merged_edges[['source','target']].apply(lambda x: "{}-{}".format(x[0],x[1]), axis=1)
print(merged_edges.drop_duplicates("edge-id").shape)
ids = merged_edges['edge-id']
merged_edges[ids.isin(ids[ids.duplicated()])].sort_values("edge-id")
# Out:
# (263756, 8)
#                                     dest_cid  \
# 125396  5f20dfc0-7631-11e4-a3cb-005056011aef
# 268771  5f20dfc0-7631-11e4-a3cb-005056011aef
# 133206  0f82316f-4fd5-45f9-b992-c14ad7504f25
# 265252  0f82316f-4fd5-45f9-b992-c14ad7504f25
# 265251  2aa74b54-b119-4dd7-8a75-ddbb030458e8
# 200859  2aa74b54-b119-4dd7-8a75-ddbb030458e8
# 242475  48c0c30d-5f04-4095-8804-d1ee8989761d
# 242474  48c0c30d-5f04-4095-8804-d1ee8989761d
# 235437  fbaa8140-e364-405f-bc09-d25ed8c18838
# 31652   fbaa8140-e364-405f-bc09-d25ed8c18838
# 48274   9acf51ab-0eb4-4134-8d69-82c77c10e60d
# 258494  9acf51ab-0eb4-4134-8d69-82c77c10e60d
#
#                                                 dest_node  source  \
# 125396  /guidance/comply-with-the-compulsory-beef-labe...   10016
# 268771  /guidance/comply-with-the-compulsory-beef-labe...   10016
# 133206            /government/publications/visit-guidance   10039
# 265252            /government/publications/visit-guidance   10039
# 265251  /government/publications/considering-human-rig...   10039
# 200859  /government/publications/considering-human-rig...   10039
# 242475          /what-different-qualification-levels-mean   10059
# 242474          /what-different-qualification-levels-mean   10059
# 46092           /what-different-qualification-levels-mean   10059
# 237727  /government/publications/application-to-recons...    1008
# 85025   /government/publications/application-to-recons...    1008
# 237736  /government/publications/application-to-recons...    1008
# 27027   /government/publications/policy-paper-on-citiz...    1008
# 237729  /government/publications/policy-paper-on-citiz...    1008
# 89387                              /check-british-citizen    1008
# 237732                             /check-british-citizen    1008
# 64102   /government/publications/undocumented-commonwe...    1008
# 237725  /government/publications/undocumented-commonwe...    1008
# 237731               /settled-status-eu-citizens-families    1008
# 23493                /settled-status-eu-citizens-families    1008
# 118941                      /types-of-british-nationality    1008
# 237735                      /types-of-british-nationality    1008
# 28463                                  /uk-border-control   10100
# 250589                                 /uk-border-control   10100
# 67161                              /bringing-cash-into-uk   10100
# 250590                             /bringing-cash-into-uk   10100
# 139083             /running-community-amateur-sports-club   10104
# 245541             /running-community-amateur-sports-club   10104
# 78481   /government/publications/charity-fundraising-e...   10104
# 245539  /government/publications/charity-fundraising-e...   10104
# ...                                                   ...     ...
# 20060   /government/collections/hs2-property-schemes-m...    9871
# 243535  /government/collections/hs2-property-schemes-m...    9871
# 243536  /government/publications/property-scheme-maps-...    9871
# 102820  /government/publications/property-scheme-maps-...    9871
# 173694  /government/publications/hs2-property-schemes-...    9871
# 243528  /government/publications/hs2-property-schemes-...    9871
# 95353                                    /check-hs2-route    9871
# 243539                                   /check-hs2-route    9871
# 83000   /prepare-file-annual-accounts-for-limited-company    9894
# 245518  /prepare-file-annual-accounts-for-limited-company    9894
# 58990   /government/publications/life-of-a-company-ann...    9894
# 245517  /government/publications/life-of-a-company-ann...    9894
# 66724          /file-your-company-accounts-and-tax-return    9894
# 245519         /file-your-company-accounts-and-tax-return    9894
# 243691                                  /universal-credit    9912
# 172653                                  /universal-credit    9912
# 150582                            /mortgage-rescue-scheme    9912
# 243694                            /mortgage-rescue-scheme    9912
# 263512             /record-delegated-driving-test-details    9920
# 212155             /record-delegated-driving-test-details    9920
# 3666                          /holiday-entitlement-rights    9930
# 235436                        /holiday-entitlement-rights    9930
# 61349         /calculate-agricultural-holiday-entitlement    9930
# 235435        /calculate-agricultural-holiday-entitlement    9930
# 136519                                    /sunday-working    9930
# 235438                                    /sunday-working    9930
# 235437                               /night-working-hours    9930
# 31652                                /night-working-hours    9930
# 48274   /government/statistics/individuals-referred-to...    9976
# 258494  /government/statistics/individuals-referred-to...    9976
edf6f8-389b-4b34-a5b1-faa9ef909a70
# 31652   deedf6f8-389b-4b34-a5b1-faa9ef909a70
# 48274   b1e99a8e-2e31-47b8-9c2b-12b16cfb6573
# 258494  b1e99a8e-2e31-47b8-9c2b-12b16cfb6573
#
#                                                  src_node  target  weight  \
# 125396  /government/collections/beef-and-veal-labellin...   46581    32.0
# 268771  /government/collections/beef-and-veal-labellin...   46581     NaN
# 133206                /government/collections/visit-visas   16460    66.0
# 265252                /government/collections/visit-visas   16460     NaN
# 265251                /government/collections/visit-visas   61143     NaN
# 200859                /government/collections/visit-visas   61143    15.0
# 242475                    /find-a-regulated-qualification   10185     NaN
# 242474                    /find-a-regulated-qualification   10185     NaN
# 46092                     /find-a-regulated-qualification   10185   432.0
# 237727                                    /right-of-abode   12850     NaN
# 85025                                     /right-of-abode   12850    65.0
# 237736                                    /right-of-abode   12850     NaN
# 27027                                     /right-of-abode   24096    37.0
# 237729                                    /right-of-abode   24096     NaN
# 89387                                     /right-of-abode   36474   292.0
# 237732                                    /right-of-abode   36474     NaN
# 64102                                     /right-of-abode    5537    38.0
# 237725                                    /right-of-abode    5537     NaN
# 237731                                    /right-of-abode   55850     NaN
# 23493                                     /right-of-abode   55850   207.0
# 118941                                    /right-of-abode   63283   107.0
# 237735                                    /right-of-abode   63283     NaN
# 28463                               /registered-traveller   12896   107.0
# 250589                              /registered-traveller   12896     NaN
# 67161                               /registered-traveller   20934    26.0
# 250590                              /registered-traveller   20934     NaN
# 139083                                  /tax-relief-cascs   26014    18.0
# 245541                                  /tax-relief-cascs   26014     NaN
# 78481                                   /tax-relief-cascs   27759    34.0
# 245539                                  /tax-relief-cascs   27759     NaN
# ...                                                   ...     ...     ...
# 20060              /claim-compensation-if-affected-by-hs2   12100   173.0
# 243535             /claim-compensation-if-affected-by-hs2   12100     NaN
# 243536             /claim-compensation-if-affected-by-hs2   26514     NaN
# 102820             /claim-compensation-if-affected-by-hs2   26514    86.0
# 173694             /claim-compensation-if-affected-by-hs2   35384    91.0
# 243528             /claim-compensation-if-affected-by-hs2   35384     NaN
# 95353              /claim-compensation-if-affected-by-hs2   59231    52.0
# 243539             /claim-compensation-if-affected-by-hs2   59231     NaN
# 83000     /audit-exemptions-for-private-limited-companies   33637   147.0
# 245518    /audit-exemptions-for-private-limited-companies   33637     NaN
# 58990     /audit-exemptions-for-private-limited-companies   39457   656.0
# 245517    /audit-exemptions-for-private-limited-companies   39457     NaN
# 66724     /audit-exemptions-for-private-limited-companies   50646   110.0
# 245519    /audit-exemptions-for-private-limited-companies   50646     NaN
# 243691                     /support-for-mortgage-interest   26857     NaN
# 172653                     /support-for-mortgage-interest   26857    15.0
# 150582                     /support-for-mortgage-interest   27841    85.0
# 243694                     /support-for-mortgage-interest   27841     NaN
# 263512          /provide-driving-tests-for-your-employees   29057     NaN
# 212155          /provide-driving-tests-for-your-employees   29057    23.0
# 3666                  /calculate-your-holiday-entitlement   10582  4587.0
# 235436                /calculate-your-holiday-entitlement   10582     NaN
# 61349                 /calculate-your-holiday-entitlement   17322   146.0
# 235435                /calculate-your-holiday-entitlement   17322     NaN
# 136519                /calculate-your-holiday-entitlement   26905    81.0
# 235438                /calculate-your-holiday-entitlement   26905     NaN
# 235437                /calculate-your-holiday-entitlement   54411     NaN
# 31652                 /calculate-your-holiday-entitlement   54411    80.0
# 48274   /government/collections/individuals-referred-t...    5269    60.0
# 258494  /government/collections/individuals-referred-t...    5269     NaN
f790dc71-386e-4440-9689-31f94e7ac64d  /universal-credit   18430
# 235003  f790dc71-386e-4440-9689-31f94e7ac64d  /universal-credit   51325
# 235004  f790dc71-386e-4440-9689-31f94e7ac64d  /universal-credit   14677
# 235006  f790dc71-386e-4440-9689-31f94e7ac64d  /universal-credit   12935
# 235008  f790dc71-386e-4440-9689-31f94e7ac64d  /universal-credit   34166
# 235009  f790dc71-386e-4440-9689-31f94e7ac64d  /universal-credit   39394
# 235010  f790dc71-386e-4440-9689-31f94e7ac64d  /universal-credit    2099
# 235017  f790dc71-386e-4440-9689-31f94e7ac64d  /universal-credit   50126
# 235018  f790dc71-386e-4440-9689-31f94e7ac64d  /universal-credit   54857
# 235020  f790dc71-386e-4440-9689-31f94e7ac64d  /universal-credit   60461
# 235021  f790dc71-386e-4440-9689-31f94e7ac64d  /universal-credit     487
# 235029  f790dc71-386e-4440-9689-31f94e7ac64d  /universal-credit   45139
# 235030  f790dc71-386e-4440-9689-31f94e7ac64d  /universal-credit   15420
# 235031  f790dc71-386e-4440-9689-31f94e7ac64d  /universal-credit    2009
#
#         weight      edge-id
# 234998     NaN  26857-18430
# 235003     NaN  26857-51325
# 235004     NaN  26857-14677
# 235006     NaN  26857-12935
# 235008     NaN  26857-34166
# 235009     NaN  26857-39394
# 235010     NaN   26857-2099
# 235017     NaN  26857-50126
# 235018     NaN  26857-54857
# 235020     NaN  26857-60461
# 235021     NaN    26857-487
# 235029     NaN  26857-45139
# 235030     NaN  26857-15420
# 235031     NaN   26857-2009

# %% [markdown]
# ## Check embeddings file

# %%
node_data_file_predict = os.path.join(PREDICT_DIR, "predict_top50_vs_all_node_data_embs_300.csv.gz")
node_data_file_train = os.path.join(content_api, "training_node_data_fixd.csv.gz")

# %%
embeddings = pd.read_csv(node_data_file_predict, compression="gzip", index_col=0)

# %%
embeddings.shape
# Out:
# (206038, 513)

# %%
embeddings1 = pd.read_csv(node_data_file_train, compression="gzip", index_col=0)

# %%
c_all = set(list(embeddings.content_id) + list(embeddings1.content_id))
len(c_all)
# Out:
# 220941

# %%
content_ids_edges = set(list(merged_edges.src_cid)+list(merged_edges.dest_cid)) 
# content_ids_functedges = set(list(edges.src_cid)+list(edges.dest_cid)) 
len(content_ids_edges)
# Out:
# 73173

# %%
len(content_ids_edges.difference(c_all))
# Out:
# 0

# %% [markdown]
# ### Count duplicate entries in embeddings

# %%
all_embeddings = pd.concat([embeddings, embeddings1], sort=True, ignore_index=True)

# %%
ids = all_embeddings['content_id']
all_embeddings[ids.isin(ids[ids.duplicated()])].sort_values("content_id")
# Out:
#                0         1        10       100       101       102       103  \
# 3994   -0.016188  0.031590  0.012646 -0.021106 -0.000546 -0.053907 -0.013014
# 221573 -0.016188  0.031590  0.012646 -0.021106 -0.000546 -0.053907 -0.013014
# 259292 -0.055287 -0.020550  0.025845  0.049996 -0.049346 -0.053477  0.036689
# 266762 -0.055287 -0.020550  0.025845  0.049996 -0.049346 -0.053477  0.036689
# 230390 -0.055287 -0.020550  0.025845  0.049996 -0.049346 -0.053477  0.036689
# 6234   -0.055287 -0.020550  0.025845  0.049996 -0.049346 -0.053477  0.036689
# 249902 -0.055287 -0.020550  0.025845  0.049996 -0.049346 -0.053477  0.036689
# 259432 -0.055287 -0.020550  0.025845  0.049996 -0.049346 -0.053477  0.036689
# 247853 -0.048413  0.046790 -0.057513 -0.045078  0.002419 -0.018005  0.054131
# 10696  -0.048413  0.046790 -0.057513 -0.045078  0.002419 -0.018005  0.054131
# 14454  -0.048617 -0.003174  0.064009 -0.056477  0.027464  0.047275  0.019767
# 262643 -0.048617 -0.003174  0.064009 -0.056477  0.027464  0.047275  0.019767
# 15591  -0.031045  0.037224 -0.058240 -0.038744 -0.002370 -0.050649  0.007794
# 9525    0.034150 -0.049190  ffd43c4a-cfee-43d8-9716-30a81ad146da
# 243067  0.034150 -0.049190  ffd43c4a-cfee-43d8-9716-30a81ad146da
# 257629  0.038209  0.030621  ffdae125-d685-4862-9b06-bba49dce1249
# 13212   0.038209  0.030621  ffdae125-d685-4862-9b06-bba49dce1249
# 250270  0.032408  0.059363  ffdf550a-f2e1-4d18-bde7-cbd1cc175762
# 11307   0.032408  0.059363  ffdf550a-f2e1-4d18-bde7-cbd1cc175762
# 15704  -0.026836 -0.037996  ffe03767-3130-4903-8579-269edf93377b
# 260293 -0.026836 -0.037996  ffe03767-3130-4903-8579-269edf93377b
# 267678 -0.026836 -0.037996  ffe03767-3130-4903-8579-269edf93377b
# 228672 -0.026836 -0.037996  ffe03767-3130-4903-8579-269edf93377b
# 243865 -0.026836 -0.037996  ffe03767-3130-4903-8579-269edf93377b
# 217608 -0.026836 -0.037996  ffe03767-3130-4903-8579-269edf93377b
# 235523  0.055541 -0.047379  ffe10aad-e71b-45c6-8b6a-22b13f434ae1
# 240203  0.055541 -0.047379  ffe10aad-e71b-45c6-8b6a-22b13f434ae1
# 8742    0.055541 -0.047379  ffe10aad-e71b-45c6-8b6a-22b13f434ae1
# 237921 -0.064042 -0.051772  ffe22070-123b-4390-8cc4-51f9d5b5cc74
# 8122   -0.064042 -0.051772  ffe22070-123b-4390-8cc4-51f9d5b5cc74
# 15340   0.059606 -0.028265  ffe40d3d-f4d6-434f-9189-fe37683266ee
# 266292  0.059606 -0.028265  ffe40d3d-f4d6-434f-9189-fe37683266ee
# 6674   -0.046862 -0.001041  ffec1ae9-0a39-42a4-8f27-e747f4bbf4f8
# 232111 -0.046862 -0.001041  ffec1ae9-0a39-42a4-8f27-e747f4bbf4f8
# 232493  0.066654 -0.015134  fff67af6-b6bb-4ced-8527-a1305dc92c36
# 6765    0.066654 -0.015134  fff67af6-b6bb-4ced-8527-a1305dc92c36
# 94     -0.034974 -0.053977  fff88e3b-ae66-43e4-afd0-6fc1f227b452
# 206362 -0.034974 -0.053977  fff88e3b-ae66-43e4-afd0-6fc1f227b452
# 243238  0.057932  0.065911  fff99356-567f-441c-9a0a-d2a04725f7ce
# 9566    0.057932  0.065911  fff99356-567f-441c-9a0a-d2a04725f7ce
# 12547   0.032244  0.047566  fffbae5b-a42f-4c61-a221-f6e2fb37108f
# 255097  0.032244  0.047566  fffbae5b-a42f-4c61-a221-f6e2fb37108f
#
# [69243 rows x 513 columns]

# %%
all_embeddings.drop_duplicates("content_id", inplace=True)

# %% [markdown]
# ### Map `content_id` to `node_id` again

# %%
nid_cid = dict(zip(merged_edges.source, merged_edges.src_cid))
for nid,cid in zip(merged_edges.target, merged_edges.dest_cid):
    if nid not in nid_cid.keys():
        nid_cid[nid] = cid

# %%
cols = [str(i) for i in range(0,512)]
cols[-1]
# Out:
# '511'

# %%
embeddings_dict = dict(zip(all_embeddings.content_id, all_embeddings[cols].values))

# %%
all_embeddings[all_embeddings.content_id=="80f7a69c-5cdc-4bd5-a16c-15d669ba2cc5"]["3"]
# Out:
# 0    0.008009
# Name: 3, dtype: float64

# %%
rowlist = []
index = []
for nid,cid in nid_cid.items():
    row_dict = {}
    row_dict["content_id"] = cid
    for i,emb in enumerate(embeddings_dict[cid]):
        row_dict[i] = emb
    rowlist.append(row_dict)  
    index.append(nid)
new_embeddings = pd.DataFrame(rowlist, index=index)

# %%
new_embeddings.head()
# Out:
#                                  content_id         0         1         2  \
# 33265  5ef7560d-7631-11e4-a3cb-005056011aef -0.047676 -0.027639  0.056349
# 58314  1e333395-5dd5-4452-96a3-fbe939928761 -0.033119  0.049818  0.042104
# 23720  d612c61e-22f4-4922-8bb2-b04b9202126e -0.067857 -0.015453 -0.028865
# 25053  305acc88-488e-44ec-8e5a-1a5de7819ba9 -0.055095  0.003975  0.034079
# 14044  305acc88-488e-44ec-8e5a-1a5de7819ba9 -0.055095  0.003975  0.034079
#
#               3         4         5         6         7         8    ...     \
# 33265 -0.009413 -0.020528 -0.045546  0.068116  0.018213  0.016371    ...
# 58314 -0.017883 -0.007372 -0.054978  0.064178  0.062335  0.011622    ...
# 23720  0.020038  0.017298 -0.064374  0.081447 -0.008263  0.021375    ...
# 25053 -0.016298 -0.041664 -0.046474  0.056651  0.056367  0.050351    ...
# 14044 -0.016298 -0.041664 -0.046474  0.056651  0.056367  0.050351    ...
#
#             502       503       504       505       506       507       508  \
# 33265  0.019222  0.066869  0.036356 -0.010981  0.030189 -0.045008  0.007033
# 58314 -0.034333  0.064000  0.063919 -0.037945  0.054777  0.023922  0.002650
# 23720  0.028531  0.019493  0.058379 -0.001819  0.070202 -0.067259  0.041385
# 25053  0.022530  0.056369  0.056647 -0.035750  0.054273  0.048701  0.021803
# 14044  0.022530  0.056369  0.056647 -0.035750  0.054273  0.048701  0.021803
#
#             509       510       511
# 33265 -0.047787 -0.001289 -0.063644
# 58314 -0.063124 -0.019809 -0.057015
# 23720 -0.066728  0.001454 -0.014244
# 25053 -0.055919  0.002437 -0.052509
# 14044 -0.055919  0.002437 -0.052509
#
# [5 rows x 513 columns]

# %%
merged_edges[merged_edges.source==25053]
# Out:
#                                     dest_cid  \
# 3       305acc88-488e-44ec-8e5a-1a5de7819ba9
# 1087    32d4d2c8-2f9c-406f-96e4-65222074642a
# 1216    686e6d1d-78c2-4c9d-b863-be5c5d8ed787
# 1220    32d4d2c8-2f9c-406f-96e4-65222074642a
# 1221    d6c2de5d-ef90-45d1-82d4-5f2438369eea
# 2019    305acc88-488e-44ec-8e5a-1a5de7819ba9
# 3593    305acc88-488e-44ec-8e5a-1a5de7819ba9
# 3608    305acc88-488e-44ec-8e5a-1a5de7819ba9
# 5181    b3fb8ff7-ac2e-4440-8c0f-227eb038c436
# 6088    58b05bc2-fde5-4a0b-af73-8edc532674f8
# 6095    305acc88-488e-44ec-8e5a-1a5de7819ba9
# 8232    1e333395-5dd5-4452-96a3-fbe939928761
# 8233    f3bbdec2-0e62-4520-a7fd-6ffd5d36e03a
# 8240    5ef7560d-7631-11e4-a3cb-005056011aef
# 8960    dc1a1744-4089-43b3-b2e3-4e397b6b15b1
# 9412    e1067450-7d13-45ff-ada4-5e3dd4025fb7
#
305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   51726
# 17754   305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   66338
# 18331   305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   49658
# 22031   305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   16539
# 22335   305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   19621
# 24099   305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   37225
# 25523   305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   64969
# ...                                      ...              ...     ...
# 147937  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   16544
# 148014  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa    7229
# 155899  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   39888
# 156337  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   13857
# 159221  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   55850
# 164385  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   21030
# 165541  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   32556
# 166675  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   24845
# 170710  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   17876
# 172961  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   31256
# 173599  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   57091
# 173849  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   64703
# 176494  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa    8763
# 177940  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   26825
# 179713  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   58048
# 183276  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   24981
# 197638  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa    7671
# 198595  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   38938
# 200045  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   51283
# 202977  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   39534
# 233900  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   50619
# 233901  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   42396
# 233902  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   61275
# 233907  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   18430
# 233909  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   49397
# 233910  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   28568
# 233911  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa    5593
# 233912  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   19104
# 233914  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   60866
# 233917  305acc88-488e-44ec-8e5a-1a5de7819ba9  /uk-family-visa   50978
#
#          weight      edge-id
# 3       26227.0  25053-14044
# 1087     2729.0  25053-28920
# 1216      543.0  25053-43124
# 1220      126.0  25053-44491
# 1221       37.0  25053-64440
# 2019     2659.0  25053-51911
# 3593     1125.0  25053-29781
# 3608     1252.0  25053-32219
# 5181     2096.0  25053-13119
# 6088       62.0  25053-56268
# 6095     2335.0  25053-26404
# 8232      102.0  25053-58314
# 8233      327.0   25053-4412
# 8240       67.0  25053-33265
# 8960     1312.0  25053-53513
# 9412      127.0  25053-44325
# 11047     160.0  25053-10574
# 12557    2702.0  25053-50568
# 13971     794.0   25053-7556
# 14132    3204.0  25053-43769
# 14654    1047.0  25053-24233
# 14989      51.0  25053-24731
# 16383      62.0  25053-18801
# 16393     162.0  25053-51726
# 17754     790.0  25053-66338
# 18331      78.0  25053-49658
# 22031    1112.0  25053-16539
# 22335      16.0  25053-19621
# 24099    1739.0  25053-37225
# 25523      16.0  25053-64969
# ...         ...          ...
# 147937     17.0  25053-16544
# 148014     21.0   25053-7229
# 155899     26.0  25053-39888
# 156337     41.0  25053-13857
# 159221     24.0  25053-55850
# 164385     96.0  25053-21030
# 165541     30.0  25053-32556
# 166675     15.0  25053-24845
# 170710     22.0  25053-17876
# 172961     18.0  25053-31256
# 173599     15.0  25053-57091
# 173849     19.0  25053-64703
# 176494     24.0   25053-8763
# 177940     26.0  25053-26825
# 179713     16.0  25053-58048
# 183276     22.0  25053-24981
# 197638     15.0   25053-7671
# 198595     15.0  25053-38938
# 200045     18.0  25053-51283
# 202977     18.0  25053-39534
# 233900      NaN  25053-50619
# 233901      NaN  25053-42396
# 233902      NaN  25053-61275
# 233907      NaN  25053-18430
# 233909      NaN  25053-49397
# 233910      NaN  25053-28568
# 233911      NaN   25053-5593
# 233912      NaN  25053-19104
# 233914      NaN  25053-60866
# 233917      NaN  25053-50978
#
# [111 rows x 8 columns]

# %%
train_network = os.path.join(DATA_DIR,"train_network")
merged_file = os.path.join(train_network, "merged_edges_struct_funct.csv.gz")
new_embeddings_file = os.path.join(train_network, "merged_embs_struct_funct.csv.gz")

# %%
merged_edges.to_csv(merged_file, compression="gzip", index=False)
new_embeddings.to_csv(new_embeddings_file, compression="gzip")
