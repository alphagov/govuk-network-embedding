# %%
import networkx as nx
import os
import pandas as pd
import numpy as np
from collections import Counter
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
processed_network = os.path.join(os.getenv("DATA_DIR"),"processed_network")

# %%
processed_network
# Out:
# '/Users/felisialoukou/Documents/govuk-network-embedding/data/processed_network'

# %%
nodefile = os.path.join(processed_network, "taxon_28_31_01_sample30_cs_nodes.csv.gz")
edgefile = os.path.join(processed_network, "taxon_28_31_01_sample30_cs_edges.csv.gz")

# %% [markdown]
# ### Load nodes

# %%
nodes = pd.read_csv(nodefile, compression="gzip", sep="\t")

# %%
# nodes.reset_index(inplace=True)
# nodes.drop("Node_id",axis=1,inplace=True)
# nodes.rename(columns={'index':"Node_id"},inplace=True)

# %%
nodes.head()
# Out:
#                                                 Node  Node_id  \
# 0  /government/publications/guidance-for-dependan...        0
# 1                                         /visa-fees        1
# 2                    /find-a-visa-application-centre        2
# 3                  /entering-staying-uk/family-visas        3
# 4                                    /uk-family-visa        4
#
#                                   Node_Taxon
# 0  ('d612c61e-22f4-4922-8bb2-b04b9202126e',)
# 1  ('29480b00-dc4d-49a0-b48c-25dda8569325',)
# 2  ('d3df7728-db52-411f-afd2-44dbd09f553b',)
# 3  ('d612c61e-22f4-4922-8bb2-b04b9202126e',)
# 4  ('d612c61e-22f4-4922-8bb2-b04b9202126e',)

# %%
nodes.shape
# Out:
# (745581, 3)

# %%
nodes = nodes[~nodes.Node.str.contains(" ")]

# %% [markdown]
# ### Load edges

# %%
edges = pd.read_csv(edgefile, compression="gzip", sep="\t")

# %%
# nid_dict = dict(zip(nodes.Node,nodes.Node_id))
# edges['Source_id'] = edges['Source_node'].map(nid_dict)
# edges['Destination_id'] = edges['Destination_node'].map(nid_dict)

# %%
edges.head()
# Out:
#                                          Source_node  Source_id  \
# 0  /government/publications/guidance-for-dependan...          0
# 1                                         /visa-fees          1
# 2                    /find-a-visa-application-centre          2
# 3                  /entering-staying-uk/family-visas          3
# 4                                    /uk-family-visa          4
#
#                     Destination_node  Destination_id  Weight  \
# 0                         /visa-fees               1      24
# 1    /find-a-visa-application-centre               2     433
# 2  /entering-staying-uk/family-visas               3       1
# 3                    /uk-family-visa               4     148
# 4     /uk-family-visa/partner-spouse               5   10863
#
#                                 Source_Taxon  \
# 0  ('d612c61e-22f4-4922-8bb2-b04b9202126e',)
# 1  ('29480b00-dc4d-49a0-b48c-25dda8569325',)
# 2  ('d3df7728-db52-411f-afd2-44dbd09f553b',)
# 3  ('d612c61e-22f4-4922-8bb2-b04b9202126e',)
# 4  ('d612c61e-22f4-4922-8bb2-b04b9202126e',)
#
#                            Destination_Taxon
# 0  ('29480b00-dc4d-49a0-b48c-25dda8569325',)
# 1  ('d3df7728-db52-411f-afd2-44dbd09f553b',)
# 2  ('d612c61e-22f4-4922-8bb2-b04b9202126e',)
# 3  ('d612c61e-22f4-4922-8bb2-b04b9202126e',)
# 4  ('d612c61e-22f4-4922-8bb2-b04b9202126e',)

# %% [markdown]
# #### Filter edge list: remove self-loops, remove edges to/from `/search`

# %%
edges[edges.Destination_node.str.contains("/search?")]
# Out:
#                                                Source_node  Source_id  \
# 738               /get-information-about-property-and-land        488
# 741      /government/publications/inspection-and-applic...        490
# 747                                                      /         13
# 1312              /topic/intellectual-property/trade-marks        717
# 2842               /government/organisations/land-registry        484
# 9496        /limited-company-formation/choose-company-name        170
# 11832    /government/statistics?keywords=&taxons[]=all&...       5214
# 13869    /limited-company-formation/appoint-directors-a...       2615
# 17160      /wills-probate-inheritance/if-youre-an-executor       1159
# 17164    /wills-probate-inheritance/once-the-grants-bee...       7299
# 17165    /wills-probate-inheritance/searching-for-proba...       7297
# 17168                           /wills-probate-inheritance        582
# 18230              /government/organisations/land-registry        484
# 20398    /get-information-about-property-and-land/copie...        485
# 20399    /get-information-about-property-and-land/searc...        489
# 20402                            /your-property-boundaries       7129
# 20403           /search-property-information-land-registry        492
# 20408    /get-information-about-property-and-land/copie...        485
# 20778         /order-copy-birth-death-marriage-certificate       6610
# 21453    /browse/housing-local-services/planning-permis...       8817
# 21457                          /topic/planning-development       8819
# 21458                  /search-register-planning-decisions       8816
# 21460       /search-register-planning-decisions/birmingham       8821
# 21797    /how-to-register-a-trade-mark/unregistered-tra...       8962
# 21802    /how-to-register-a-trade-mark/what-you-can-and...       8965
# 21806    /government/publications/how-to-classify-trade...       8966
# 22134                           /wills-probate-inheritance        582
# 22508              /government/organisations/land-registry        484
# 22510                            /check-house-price-trends       5216
# 23737    /your-property-boundaries/correct-boundary-mis...       9652
# ...                                                    ...        ...
# 2481853  /government/publications/apprenticeship-standa...     141258
# 2481856  /government/news/hm-land-registry-launches-new...     262389
# 2482430                                      /get-dna-test      22642
# 2482587  /government/collections/requests-for-personal-...      14940
# 2482735  /government/news/gb-patents-available-on-paten...     596329
# 2482822      /guidance/inspire-index-polygons-spatial-data      91468
# 2482897  /government/publications/application-to-regist...      42189
# 2483663  /dfid-research-outputs/overseas-road-note-5-a-...     702280
# 2483715                     /building-regulations-approval      10130
# 2483885                        /check-income-tax-last-year       2198
# 2484175                   /local-library-services/coventry     738750
# 2484280  /government/organisations/latest?organisations...      52784
# 2484697                /copyright/how-long-copyright-lasts      25708
# 2485030  /search-the-register-of-disqualified-company-d...      13768
# 2485031              /search-bankruptcy-insolvencyregister     738973
# 2486361        /search-property-information-land-registery     739329
# 2486538  /government/uploads/system/uploads/attachment_...     170381
# 2486919       /order-copy-birth-death-marriage-certificate       6610
# 2488022  /guidance/how-to-register-and-use-the-apprenti...      51594
# 2488053  /government/publications/searching-for-similar...      43255
# 2495141  /print/government/publications/personal-insolv...     304811
# 2495145  /government/publications/providing-services-in...       3003
# 2495332    /done/search-property-information-land-registry      30261
# 2496093  /government/organisations/hm-revenue-customs/c...       1554
# 2496172  /government/publications/change-the-register-a...      28150
# 2497439                                    /browse/driving        557
# 2499763  /government/publications/private-trusts-of-lan...      25720
# 2503510                /how-to-register-a-trade-mark/apply       6535
# 2503598                       /apply-for-disabled-bus-pass      15889
# 2505023                                    /tier-2-general        613
#
#                                           Destination_node  Destination_id  \
# 738      /get-information-about-property-and-land/searc...             489
# 741      /get-information-about-property-and-land/searc...             489
# 747             /search-property-information-land-registry             492
# 1312                          /search-trade-mark-decisions             725
# 2842          /topic/land-registration/searches-fees-forms            1496
# 9496                                 /search-for-trademark            4258
# 11832                                 /search-house-prices            5215
# 13869               /search-bankruptcy-insolvency-register            5222
# 17160    /wills-probate-inheritance/searching-for-proba...            7297
# 17164    /wills-probate-inheritance/searching-for-proba...            7297
# 17165                                 /search-will-probate            7300
# 17168    /wills-probate-inheritance/searching-for-proba...            7297
# 18230           /search-property-information-land-registry             492
# 20398    /get-information-about-property-and-land/searc...             489
# 20399           /search-property-information-land-registry             492
# 20402           /search-property-information-land-registry             492
# 20403         /topic/land-registration/searches-fees-forms            1496
# 20408           /search-property-information-land-registry             492
# 20778                               /search-local-archives            8547
# 21453                  /search-register-planning-decisions            8816
# 21457                  /search-register-planning-decisions            8816
# 21458       /search-register-planning-decisions/birmingham            8821
# 21460                  /search-register-planning-decisions            8816
# 21797                                /search-for-trademark            4258
# 21802                                /search-for-trademark            4258
# 21806                                /search-for-trademark            4258
# 22134                                 /search-will-probate            7300
# 22508                                 /search-house-prices            5215
# 22510                                 /search-house-prices            5215
# 23737           /search-property-information-land-registry             492
# ...                                                    ...             ...
# 2481853      /guidance/search-for-apprenticeship-standards           21234
# 2481856       /topic/land-registration/searches-fees-forms            1496
# 2482430  /wills-probate-inheritance/searching-for-proba...            7297
# 2482587         /search-property-information-land-registry             492
# 2482735                                 /search-for-patent           13046
# 2482822         /search-property-information-land-registry             492
# 2482897                                 /search-for-patent           13046
# 2483663                              /search-for-trademark            4258
# 2483715                             /search-local-archives            8547
# 2483885         /search-property-information-land-registry             492
# 2484175                          /search-library-catalogue           32404
# 2484280  /government/publications/search-public-guardia...           32497
# 2484697                              /search-for-trademark            4258
# 2485030              /search-bankruptcy-insolvencyregister          738973
# 2485031             /search-bankruptcy-insolvency-register            5222
# 2486361         /search-property-information-land-registry             492
# 2486538                              /search-for-trademark            4258
# 2486919                              /search-for-trademark            4258
# 2488022      /guidance/search-for-apprenticeship-standards           21234
# 2488053                       /search-trade-mark-decisions             725
# 2495141  /government/publications/searches-of-the-index...           24838
# 2495145         /search-property-information-land-registry             492
# 2495332         /search-property-information-land-registry             492
# 2496093                               /search-will-probate            7300
# 2496172       /topic/land-registration/searches-fees-forms            1496
# 2497439  /get-information-about-property-and-land/searc...             489
# 2499763       /topic/land-registration/searches-fees-forms            1496
# 2503510                                 /search-for-patent           13046
# 2503598                /search-register-planning-decisions            8816
# 2505023       /topic/land-registration/searches-fees-forms            1496
#
#          Weight                                       Source_Taxon  \
# 738        1851  ('55f1135f-2b81-440f-9d5b-52f593f4b9ad', '0c46...
# 741           1  ('495afdb6-47be-4df1-8b38-91c8adb1eefc', '4ad6...
# 747         394                                         ('other',)
# 1312        299          ('d949275c-88f8-4623-a44b-eb3706651e10',)
# 2842       5428                                         ('other',)
# 9496        594  ('386180ca-4219-478e-8b80-a271dd5ce5f2', 'c3bc...
# 11832         1                                         ('other',)
# 13869        34  ('386180ca-4219-478e-8b80-a271dd5ce5f2', 'c3bc...
# 17160        57  ('3bc4ec93-fd86-4c66-98d0-7623cbbaa6be', '0fff...
# 17164       105  ('3bc4ec93-fd86-4c66-98d0-7623cbbaa6be', '0fff...
# 17165     15426  ('3bc4ec93-fd86-4c66-98d0-7623cbbaa6be', '0fff...
# 17168      2889  ('3bc4ec93-fd86-4c66-98d0-7623cbbaa6be', '0fff...
# 18230     20359                                         ('other',)
# 20398      3899  ('55f1135f-2b81-440f-9d5b-52f593f4b9ad', '0c46...
# 20399      6392  ('55f1135f-2b81-440f-9d5b-52f593f4b9ad', '0c46...
# 20402      1968  ('55f1135f-2b81-440f-9d5b-52f593f4b9ad', '0c46...
# 20403       345  ('55f1135f-2b81-440f-9d5b-52f593f4b9ad', '0c46...
# 20408      4693  ('55f1135f-2b81-440f-9d5b-52f593f4b9ad', '0c46...
# 20778       339  ('f875c256-b84a-417a-b2b5-ff7e301a41c7', '27db...
# 21453        84                                         ('other',)
# 21457         1          ('e486f44b-2af1-4bc2-ba5a-418f0a771413',)
# 21458        86          ('e486f44b-2af1-4bc2-ba5a-418f0a771413',)
# 21460         7          ('e486f44b-2af1-4bc2-ba5a-418f0a771413',)
# 
('55f1135f-2b81-440f-9d5b-52f593f4b9ad', '0c46...
# 2499763                                         ('other',)
# 2503510  ('afeebd0f-2494-421e-92b2-d91c3549c432', 'cb16...
# 2503598          ('e486f44b-2af1-4bc2-ba5a-418f0a771413',)
# 2505023                                         ('other',)
#
# [3649 rows x 7 columns]

# %%
for value in edges[edges.Destination_node.str.contains("/search?")].head(10).values:
    print(value)
    print("=======")
# Out:
# ['/get-information-about-property-and-land' 488
#  '/get-information-about-property-and-land/search-the-register' 489 1851
#  "('55f1135f-2b81-440f-9d5b-52f593f4b9ad', '0c46aba4-1986-4574-b957-734c6d104546')"
#  "('55f1135f-2b81-440f-9d5b-52f593f4b9ad', '0c46aba4-1986-4574-b957-734c6d104546')"]
# =======
# ['/government/publications/inspection-and-application-for-official-copies'
#  490 '/get-information-about-property-and-land/search-the-register' 489 1
#  "('495afdb6-47be-4df1-8b38-91c8adb1eefc', '4ad66168-274d-4d83-9195-f4ab0ccc97cb', '82730dd2-4ead-4ae6-943b-2c910e758279')"
#  "('55f1135f-2b81-440f-9d5b-52f593f4b9ad', '0c46aba4-1986-4574-b957-734c6d104546')"]
# =======
# ['/' 13 '/search-property-information-land-registry' 492 394 "('other',)"
#  "('55f1135f-2b81-440f-9d5b-52f593f4b9ad', '0c46aba4-1986-4574-b957-734c6d104546')"]
# =======
# ['/topic/intellectual-property/trade-marks' 717
#  '/search-trade-mark-decisions' 725 299
#  "('d949275c-88f8-4623-a44b-eb3706651e10',)"
#  "('90c7fbe9-e78e-4b36-b3ba-c1637c28326d', '584eeb89-a08e-4a93-a5ac-3540bada1c23')"]
# =======
# ['/government/organisations/land-registry' 484
#  '/topic/land-registration/searches-fees-forms' 1496 5428 "('other',)"
#  "('other',)"]
# =======
# ['/limited-company-formation/choose-company-name' 170
#  '/search-for-trademark' 4258 594
#  "('386180ca-4219-478e-8b80-a271dd5ce5f2', 'c3bc9a54-2d49-4236-962a-8414c6c33a86')"
#  "('90c7fbe9-e78e-4b36-b3ba-c1637c28326d', '584eeb89-a08e-4a93-a5ac-3540bada1c23')"]
# =======
# ['/government/statistics?keywords=&taxons[]=all&departments[]=ministry-of-housing-communities-and-local-government&from_date=&to_date='
#  5214 '/search-house-prices' 5215 1 "('other',)"
#  "('55f1135f-2b81-440f-9d5b-52f593f4b9ad', '0c46aba4-1986-4574-b957-734c6d104546')"]
# =======
# ['/search-bankruptcy-insolvency-register' 5222
#  '/search-bankruptcy-insolvency-register' 5222 7158
#  "('7c4cf197-2dba-4a82-83e2-6c8bb332525c',)"
#  "('7c4cf197-2dba-4a82-83e2-6c8bb332525c',)"]
# =======
# ['/limited-company-formation/appoint-directors-and-company-secretaries'
#  2615 '/search-bankruptcy-insolvency-register' 5222 34
#  "('386180ca-4219-478e-8b80-a271dd5ce5f2', 'c3bc9a54-2d49-4236-962a-8414c6c33a86')"
#  "('7c4cf197-2dba-4a82-83e2-6c8bb332525c',)"]
# =======
# ['/wills-probate-inheritance/if-youre-an-executor' 1159
#  '/wills-probate-inheritance/searching-for-probate-records' 7297 57
#  "('3bc4ec93-fd86-4c66-98d0-7623cbbaa6be', '0fffa994-b76d-4539-8bf9-2a6c6751580d', '4b118ae1-d783-47a8-bdec-905a1bf2ca9e')"
#  "('3bc4ec93-fd86-4c66-98d0-7623cbbaa6be', '0fffa994-b76d-4539-8bf9-2a6c6751580d', '4b118ae1-d783-47a8-bdec-905a1bf2ca9e')"]
# =======

# %%
# import re
# re.match("+")
# for page in ["/search","/search/advanced/",
#              "/search-skf=1dks",
#              "/get-information-about-property-and-land/search-the-register",
#              "/search?w", "/search?q=form4+8"]:
#     if not (re.match(r"^/search[//?|/]", page) or page=="/search"):
#         print(page)

# %%
edges[edges.Destination_node.str.contains("/search?")].shape, edges[edges.Destination_node.str.
                                                                    contains("/search?")].Weight.sum()
# Out:
# ((4032, 7), 229313)

# %%
edges = edges[(~edges.Source_node.str.contains(" ")) & (~edges.Destination_node.str.contains(" "))]
edges = edges[edges.Source_node!=edges.Destination_node]
# edges = edges[(~edges.Source_node.str.contains("/search?")) & (~edges.Destination_node.str.contains("/search?"))]

# %%
edges.shape
# Out:
# (2383883, 7)

# %%
edges[(edges.Source_node.str.contains("/search?"))]
# Out:
#                                                Source_node  Source_id  \
# 739      /get-information-about-property-and-land/searc...        489
# 742      /get-information-about-property-and-land/searc...        489
# 2843          /topic/land-registration/searches-fees-forms       1496
# 9497                                 /search-for-trademark       4258
# 11833                                 /search-house-prices       5215
# 11846               /search-bankruptcy-insolvency-register       5222
# 12244         /topic/land-registration/searches-fees-forms       1496
# 13870               /search-bankruptcy-insolvency-register       5222
# 17161    /wills-probate-inheritance/searching-for-proba...       7297
# 17165    /wills-probate-inheritance/searching-for-proba...       7297
# 17167                                 /search-will-probate       7300
# 17169    /wills-probate-inheritance/searching-for-proba...       7297
# 18231           /search-property-information-land-registry        492
# 20399    /get-information-about-property-and-land/searc...        489
# 20400           /search-property-information-land-registry        492
# 20403           /search-property-information-land-registry        492
# 20780                               /search-local-archives       8547
# 21450                  /search-register-planning-decisions       8816
# 21454                  /search-register-planning-decisions       8816
# 21458                  /search-register-planning-decisions       8816
# 21460       /search-register-planning-decisions/birmingham       8821
# 21799                                /search-for-trademark       4258
# 21803                                /search-for-trademark       4258
# 21807                                /search-for-trademark       4258
# 22135                                 /search-will-probate       7300
# 22491         /topic/land-registration/searches-fees-forms       1496
# 22511                                 /search-house-prices       5215
# 23738           /search-property-information-land-registry        492
# 24044    /get-information-about-property-and-land/searc...        489
# 24046           /search-property-information-land-registry        492
# ...                                                    ...        ...
# 2486204             /search-bankruptcy-insolvency-register       5222
# 2486361        /search-property-information-land-registery     739329
# 2486692         /search-property-information-land-registry        492
# 2487501         /search-property-information-land-registry        492
# 2487633         /search-property-information-land-registry        492
# 2488053  /government/publications/searching-for-similar...      43255
# 2488209                               /search-will-probate       7300
# 2488519       /search-register-planning-decisions/sandwell     152021
# 2488560         /search-property-information-land-registry        492
# 2489775         /search-property-information-land-registry        492
# 2492160                                 /search-for-patent      13046
# 2492177  /search-the-register-of-disqualified-company-d...      13768
# 2492882                              /search-for-trademark       4258
# 2494057             /search-bankruptcy-insolvency-register       5222
# 2494495         /search-local-archives/west-dunbartonshire     565398
# 2495142  /print/government/publications/searches-of-the...     173869
# 2495332    /done/search-property-information-land-registry      30261
# 2497744                   /search-local-archives/blackpool     191363
# 2497840  /search-the-register-of-disqualified-company-d...      13768
# 2498118                                 /search-for-patent      13046
# 2498734                               /search-house-prices       5215
# 2499117  /search-register-planning-decisions/south-nort...     195704
# 2499118  /search-register-planning-decisions/south-nort...     195704
# 2500346         /search-register-planning-decisions/harlow      81174
# 2500829         /search-property-information-land-registry        492
# 2501167                              /search-for-trademark       4258
# 2501962   /search-register-planning-decisions/chesterfield      79239
# 2503083         /search-property-information-land-registry        492
# 2503859         /search-property-information-land-registry        492
# 2505024       /topic/land-registration/searches-fees-forms       1496
#
#                                           Destination_node  Destination_id  \
# 739      /get-information-about-property-and-land/copie...             485
# 742               /get-information-about-property-and-land             488
# 2843        /government/collections/hm-land-registry-forms            1497
# 9497                            /limited-company-formation             169
# 11833                            /check-house-price-trends            5216
# 11846                                          /bankruptcy            5223
# 12244    /government/collections/fees-hm-land-registry-...            4624
# 13870    /limited-company-formation/appoint-directors-a...            2615
# 17161    /wills-probate-inheritance/stopping-a-grant-of...            7298
# 17165                                 /search-will-probate            7300
# 17167                           /wills-probate-inheritance             582
# 17169                          /browse/tax/inheritance-tax             197
# 18231              /government/organisations/land-registry             484
# 20399           /search-property-information-land-registry             492
# 20400                            /your-property-boundaries            7129
# 20403         /topic/land-registration/searches-fees-forms            1496
# 20780    /government/publications/family-tree-guide-to-...            8548
# 21450    /browse/housing-local-services/planning-permis...            8817
# 21454                          /topic/planning-development            8819
# 21458       /search-register-planning-decisions/birmingham            8821
# 21460                  /search-register-planning-decisions            8816
# 21799               /browse/business/intellectual-property            8963
# 21803                        /how-to-register-a-trade-mark            8964
# 21807    /guidance/pe-and-sport-premium-for-primary-sch...            8967
# 22135                  /inherits-someone-dies-without-will            1272
# 22491    /government/publications/official-copies-of-do...             486
# 22511              /government/organisations/land-registry             484
# 23738                   /guidance/contact-hm-land-registry             491
# 24044    /government/publications/official-copies-of-re...             487
# 24046             /get-information-about-property-and-land             488
# ...                                                    ...             ...
# 2486204                                        /insolvency          282462
# 2486361         /search-property-information-land-registry             492
# 2486692  /government/news/first-public-property-map-cou...          495631
# 2487501      /biometric-residence-permits/replace-visa-brp           17744
# 2487633  /government/publications/tackling-unlawful-sub...          346881
# 2488053                       /search-trade-mark-decisions             725
# 2488209                           /capital-gains-tax/rates            3720
# 2488519                          /find-local-consultations           55545
# 2488560                                     /browse/abroad              36
# 2489775  /government/publications/vat-notification-of-a...           10415
# 2492160  /guidance/electrical-equipment-manufacturers-a...           24915
# 2492177   /limited-company-formation/register-your-company             162
# 2492882                                       /make-a-sorn            1061
# 2494057  /guidance/automatic-disqualification-rules-for...           24206
# 2494495           /get-information-about-property-and-land             488
# 2495142  /government/publications/notices-restrictions-...           24063
# 2495332         /search-property-information-land-registry             492
# 2497744                            /local-library-services           19155
# 2497840  /government/statistics/insolvency-statistics-o...          297592
# 2498118  /topic/medicines-medical-devices-blood/payment...          742918
# 2498734                                       /contact-voa           19147
# 2499117                 /planning-permission-england-wales            5433
# 2499118  /browse/housing-local-services/planning-permis...            8817
# 2500346                                /find-local-council             354
# 2500829           /government/collections/family-law-forms           15301
# 2501167  /government/publications/request-to-restore-an...          162476
# 2501962  /browse/housing-local-services/planning-permis...            8817
# 2503083  /government/publications/ha0-1el-veolia-es-uk-...          744651
# 2503859  /government/statistics?departments[]=land-regi...          129234
# 2505024                                         /visa-fees               1
#
#          Weight                                       Source_Taxon  \
# 739        1123  ('55f1135f-2b81-440f-9d5b-52f593f4b9ad', '0c46...
# 742         476  ('55f1135f-2b81-440f-9d5b-52f593f4b9ad', '0c46...
# 2843       1324                                         ('other',)
# 9497         20  ('90c7fbe9-e78e-4b36-b3ba-c1637c28326d', '584e...
# 11833       829  ('55f1135f-2b81-440f-9d5b-52f593f4b9ad', '0c46...
#
# 2488519  ('15191831-40b4-4f6e-ade3-e82d7c775afd', 'e486...
# 2488560                                         ('other',)
# 2489775          ('e04c9a5c-88e8-46e5-91d9-add405e098fb',)
# 2492160          ('d34ba9b3-28d8-40d5-a2d3-f52d216c2590',)
# 2492177  ('386180ca-4219-478e-8b80-a271dd5ce5f2', 'c3bc...
# 2492882          ('d1e5dcf5-5f36-4838-bcb6-f0068eddb8a7',)
# 2494057          ('80cb30f4-0361-49ea-ad84-bc10910318bf',)
# 2494495  ('55f1135f-2b81-440f-9d5b-52f593f4b9ad', '0c46...
# 2495142  ('495afdb6-47be-4df1-8b38-91c8adb1eefc', '4ad6...
# 2495332  ('55f1135f-2b81-440f-9d5b-52f593f4b9ad', '0c46...
# 2497744          ('15191831-40b4-4f6e-ade3-e82d7c775afd',)
# 2497840          ('495afdb6-47be-4df1-8b38-91c8adb1eefc',)
# 2498118                                         ('other',)
# 2498734  ('68cc0b3c-7f80-4869-9dc7-b2ceef5f4f08', '107b...
# 2499117  ('68cc0b3c-7f80-4869-9dc7-b2ceef5f4f08', 'e486...
# 2499118                                         ('other',)
# 2500346          ('15191831-40b4-4f6e-ade3-e82d7c775afd',)
# 2500829          ('ba951b09-5146-43be-87af-44075eac3ae9',)
# 2501167          ('495afdb6-47be-4df1-8b38-91c8adb1eefc',)
# 2501962                                         ('other',)
# 2503083          ('3cf97f69-84de-41ae-bc7b-7e2cc238fa58',)
# 2503859                                         ('other',)
# 2505024          ('29480b00-dc4d-49a0-b48c-25dda8569325',)
#
# [3951 rows x 7 columns]

# %%
edges.sort_values(by="Weight", ascending=False)[["Source_node","Destination_node","Weight"]].head()
# Out:
#                                        Source_node  \
# 252      /government/organisations/companies-house
# 20         /log-in-file-self-assessment-tax-return
# 210   /government/organisations/hm-revenue-customs
# 226                   /self-assessment-tax-returns
# 2299                             /universal-credit
#
#                                        Destination_node   Weight
# 252                    /get-information-about-a-company  6977581
# 20    /log-in-file-self-assessment-tax-return/sign-i...  3627688
# 210               /log-in-register-hmrc-online-services  3020415
# 226             /log-in-file-self-assessment-tax-return  1936111
# 2299                          /sign-in-universal-credit  1804534

# %%
edges.shape, edges[edges.Weight >= 3].shape
# Out:
# ((2383883, 7), (454260, 7))

# %% [markdown]
# ## Initialize functional graph

# %%
graph = nx.DiGraph()

# %%
# nodes_list = [[tup.Node,{"id":tup.Node_id, "taxon":tup.Node_Taxon}] for tup in nodes.itertuples()]
# print(nodes_list[0:10])
# graph.add_nodes_from(nodes_list)

# %%
edge_list = [(tup.Source_node, tup.Destination_node, {"weight":tup.Weight}) 
             for tup in edges.itertuples() if tup.Weight >= 3]

# %%
import gzip

# %%
with gzip.open(os.path.join(processed_network, "graphsage_test.csv.gz"), "wb") as writer:
    writer.write("source\ttarget\tweight\n".encode())
    for src,tgt,d in edge_list:
        writer.write("{}\t{}\t{}\n".format(src,tgt,d['weight']).encode())

# %%
graph.add_edges_from(edge_list)

# %%
nx.info(graph)

# %%
nx.is_connected(graph.to_undirected())

# %%
len(list(nx.connected_components(graph.to_undirected())))

# %%
for i,cc in enumerate(nx.connected_components(graph.to_undirected())):
    if len(cc) > 10000:
        print(i,len(cc))

# %%
largest_cc = max(nx.connected_components(graph.to_undirected()), key=len)
list(largest_cc)[0:10]

# %%
subgraph = graph.subgraph(largest_cc)
nx.info(subgraph)

# %% [markdown]
#     'Name: \nType: DiGraph\nNumber of nodes: 146748\nNumber of edges: 514181\nAverage in degree:   3.5038\nAverage out degree:   3.5038'

# %%
attrs = {"node_id":{},"node_taxon":{}}
for tup in nodes.itertuples():
    if tup.Node in subgraph.nodes():
        attrs["node_id"][tup.Node] = tup.Node_id
        attrs["node_taxon"][tup.Node] = tup.Node_Taxon

# %%
list(attrs["node_id"].items())[0:10]

# %%
nx.set_node_attributes(graph, attrs["node_id"], 'nid')
nx.set_node_attributes(graph, attrs["node_taxon"], 'taxon')

# %%
for node,data in list(subgraph.nodes(data=True))[0:2]:
    print(node,data.keys())

# %% [markdown]
# ### Compute shortest path

# %%
short_paths = nx.shortest_path(subgraph, source="/")

# %%
len(short_paths)

# %%
count = 0
for key,value in short_paths.items():
    if len(value) > 15:
        count+=1
count

# %% [markdown]
# #### Average shortest path across all nodes

# %%
# %timeit nx.average_shortest_path_length(subgraph)

# %% [markdown]
# #### Djikstra and A*

# %%
# %timeit djik_pairs = nx.all_pairs_dijkstra_path(subgraph,weight='weight')

# %%
a_star_paths = {}
for i,(src,d) in enumerate(list(subgraph.nodes(data=True))[0:100]):
    a_star_paths[src] = {}
    print(i)
    for dest,d2 in list(subgraph.nodes(data=True))[0:100]:
        if src != dest:
            path = None
            try:
                path = nx.astar_path(subgraph, src, dest, weight='weight')        
            except nx.NetworkXNoPath:
                print("no path:",src,dest)
            a_star_paths[src][dest] = path

# %%
# filename = os.path.join(processed_network,"sampled_clean_nodes.csv.gz")
# import gzip
# with gzip.open(filename,"wb") as writer:
#     writer.write("Node\n".encode())
#     for node in subgraph.nodes():
#         writer.write("{}\n".format(node).encode())

# %% [markdown]
# ### Subtrees from all pages, compute subtree depth

# %%
home_edges = list(nx.dfs_edges(subgraph, source='/'))

# %%
home_graph = subgraph.edge_subgraph(home_edges).copy()

# %%
len(nx.shortest_path_length(home_graph, "/"))

# %% [markdown]
# ## Degree histogram

# %%
max_in = max([d for n, d in subgraph.in_degree()])
max_out = max([d for n, d in subgraph.out_degree()])
max_all = max([d for n, d in subgraph.degree()])
max_in,max_out,max_all

# %%
subgraph.in_degree("/"),subgraph.out_degree("/")

# %%
high_in = {"https://www.gov.uk"+n : d for n, d in subgraph.in_degree() if d > 500}

# %%
for key,value in high_in.items():
    print(key,value)

# %%
[n for n, d in subgraph.degree() if d == 9505]

# %%
degree_sequence = sorted([d for n, d in subgraph.degree()], reverse=True)  # degree sequence
# print "Degree sequence", degree_sequence
degreeCount = Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())
plt.figure(figsize=(20,10))
plt.plot(deg, cnt, '.')
plt.xscale('log')
plt.yscale('log')
plt.title('Degree distribution')
txt = "For pages extracted from edge_weight >= 3 sampled functional network 28-31/01/19."
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=12)
plt.xlabel('K')
plt.ylabel('P_K')
plt.show()
